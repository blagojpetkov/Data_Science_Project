# %%
import numpy as np
import pandas as pd
from urllib.parse import urlparse

import requests
from bs4 import BeautifulSoup
from IPython.display import HTML
# Setting up 'requests' to make HTTPS requests properly takes some extra steps... we'll skip them for now.
requests.packages.urllib3.disable_warnings()
# Import all modules that are required
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

import time

# %%
def generate_week_strings(start_year, start_week, end_year, end_week):
    week_strings = []

    for year in range(start_year, end_year + 1):
        start = start_week if year == start_year else 1
        end = end_week if year == end_year else 53

        for week in range(start, end + 1):
          #TODO CHANGE LATER range(1, 11)
          for num in range(1, 2):
            #TODO CHANGE LATER range(1, 11)
            week_string = f"week/{year}/{week}/{num}"
            week_strings.append(week_string)

    return week_strings

start_year = 2019
start_week = 15
end_year = 2019
end_week = 20

week_strings = generate_week_strings(start_year, start_week, end_year, end_week)

# %%
len(week_strings)
# Out:
# 6

# %%
week_strings
# Out:
# ['week/2019/15/1',
#  'week/2019/16/1',
#  'week/2019/17/1',
#  'week/2019/18/1',
#  'week/2019/19/1',
#  'week/2019/20/1']

# %%
list_of_articles = []
list_of_time_mk_urls = []
for week_string in week_strings:
  week_url = "https://time.mk/" + week_string
  response = requests.get(week_url)
  response.encoding = 'utf-8'
  soup = BeautifulSoup(response.text, "html.parser")
  list_of_articles.extend(soup.find_all(class_="cluster"))
for article in list_of_articles:
  first_anchor_tag = article.select_one('a')
  list_of_time_mk_urls.append("https://time.mk/" + first_anchor_tag.get("href"))

# %%
print(list_of_time_mk_urls)
# Out:
# ['https://time.mk/r/c7f1686700/5e0f2e175f/', 'https://time.mk/r/39a7769074/0009000555/', 'https://time.mk/r/16ac9e0813/b627b2264c/', 'https://time.mk/r/a9fe13f048/9b0b8b7d8f/', 'https://time.mk/r/4fc944c962/9d15f427f5/', 'https://time.mk/r/97cef285e3/6deea06424/', 'https://time.mk/r/411b86dd22/3338b8c192/', 'https://time.mk/r/5883fb2934/4d51fa6f5d/', 'https://time.mk/r/e8ef900c87/2ea150d3af/', 'https://time.mk/r/b242213079/0029a8beec/', 'https://time.mk/r/e2bf3cdf59/76e2c242aa/', 'https://time.mk/r/cf070e2f0b/49809a695b/', 'https://time.mk/r/31dfd504ab/680101158d/', 'https://time.mk/r/5e18a497a7/14bdade925/', 'https://time.mk/r/37e3b066a4/0ef327ba57/', 'https://time.mk/r/001ea94025/d840eda0e5/', 'https://time.mk/r/677e518d59/4c23472f1d/', 'https://time.mk/r/a66751842a/9659ed2108/', 'https://time.mk/r/4ed844801e/fd27b67662/', 'https://time.mk/r/22b2ce97ff/34e23ea868/', 'https://time.mk/r/473d387da8/da0804e7c3/', 'https://time.mk/r/f3359c04e9/e0cb30f95d/', 'https://time.mk/r/e707d5c947/963ba52c37/', 'https://time.mk/r/322afa7aa8/8b5ea13588/', 'https://time.mk/r/dc1b98dac7/605e533d39/', 'https://time.mk/r/1a4b2df89d/600c382268/', 'https://time.mk/r/326196c37a/c4891ab6ad/', 'https://time.mk/r/3067f1fe69/ce39024044/', 'https://time.mk/r/d54513a8fc/4da91aa325/', 'https://time.mk/r/4b41d17e5f/562cb7afd6/', 'https://time.mk/r/325841d1eb/45874fc3c3/', 'https://time.mk/r/95c7ce0c99/5dfb510f08/', 'https://time.mk/r/3432fbefd4/0c71b82ca3/', 'https://time.mk/r/5ea35cce26/85f2b8b7f1/', 'https://time.mk/r/16417b8a9c/ad49e22c9a/', 'https://time.mk/r/21e9a3633d/21b09abd59/', 'https://time.mk/r/cae09c590e/4e7e60c90c/', 'https://time.mk/r/8ea2c723c5/34c040debe/', 'https://time.mk/r/a8e8b548c0/de37ff2518/', 'https://time.mk/r/0de058a4c7/1e754e690b/', 'https://time.mk/r/1c4e3cc64b/60e358f416/', 'https://time.mk/r/cb01954219/0396bdc6ad/', 'https://time.mk/r/360b45c3a4/2247d67e39/', 'https://time.mk/r/17110a72b4/0bfb0d749d/', 'https://time.mk/r/445ba7718a/a8f85a92d4/', 'https://time.mk/r/abcda508f5/9b18e330ef/', 'https://time.mk/r/72e3cda882/990d791560/', 'https://time.mk/r/537e479b85/1654f0f09a/', 'https://time.mk/r/a24fdc4aa4/df7447e7c7/', 'https://time.mk/r/7c1e80f9af/da9973adaa/', 'https://time.mk/r/cb2750b397/c0220ff01a/', 'https://time.mk/r/dcffde56ea/ed7c7b115d/', 'https://time.mk/r/3dfe018c82/0e86357c4a/', 'https://time.mk/r/36ff9aaa52/ce12324cdf/', 'https://time.mk/r/3ca3806d64/d9566bc360/', 'https://time.mk/r/387aa41767/03c7daad12/', 'https://time.mk/r/84c35452ad/f3340924ed/', 'https://time.mk/r/4ce2c9f71c/9b293aec2c/', 'https://time.mk/r/442aa55fd9/010f25b2db/', 'https://time.mk/r/48914aa47b/05f428f03a/']

# %%
len(list_of_time_mk_urls)
# Out:
# 60

# %%
def parseVecerNews(url, content):
    
  soup = BeautifulSoup(content, 'html.parser')

  title = soup.find(class_='entry-title').text.strip() if soup.find(class_='entry-title') else None
  # subtitle = soup.find(class_='td-post-sub-title').text.strip() if soup.find(class_='td-post-sub-title') else None
  subtitle = soup.find(class_='entry-title').text.strip() if soup.find(class_='entry-title') else None
  date = soup.find(class_='entry-date updated td-module-date').text.strip() if soup.find(class_='entry-date updated td-module-date') else None
  main_content = soup.find(class_='td-post-content').text.strip() if soup.find(class_='td-post-content') else None

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseNovaMakedonijaNews(url, content):
  
  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  subtitle = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  date = soup.find(class_='entry-date updated td-module-date').text.strip() if soup.find(class_='entry-date updated td-module-date') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseTv21News(url, content):

  soup = BeautifulSoup(content, 'html.parser')
  title = soup.find(class_='tdb-title-text').text.strip() if soup.find(class_='tdb-title-text') else None
  subtitle = soup.find(class_='tdb-title-text').text.strip() if soup.find(class_='tdb-title-text') else None
  date = soup.find(class_='entry-date updated td-module-date').text.strip() if soup.find(class_='entry-date updated td-module-date') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = '\n'.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parse360stepeni(url, content):

  soup = BeautifulSoup(content, 'html.parser')
  title = soup.find(class_='txt--white txt--center').text.strip() if soup.find(class_='txt--white txt--center') else None
  subtitle = soup.find(class_='txt--white txt--center').text.strip() if soup.find(class_='txt--white txt--center') else None
  date = soup.find(class_='single__post-meta single__post_author txt--center').text.strip() if soup.find(class_='single__post-meta single__post_author txt--center') else None
  main_content = soup.find(class_='entry-content').text.strip() if soup.find(class_='entry-content') else None
  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseAlfaNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')

  title = soup.find(class_='entry-title').text.strip() if soup.find(class_='entry-title') else None
  subtitle = soup.find(class_='entry-title').text.strip() if soup.find(class_='entry-title') else None
  date = soup.find(class_='item-metadata posts-date').text.strip() if soup.find(class_='item-metadata posts-date') else None
  main_content = soup.find(class_='entry-content').text.strip() if soup.find(class_='entry-content') else None

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSitelNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find('div', class_='panel-pane pane-node-title').find("h1").text.strip() if soup.find('div', class_='panel-pane pane-node-title').find("h1") else None
  subtitle = soup.find('div', class_='panel-pane pane-node-title').find("h1").text.strip() if soup.find('div', class_='panel-pane pane-node-title').find("h1") else None
  date = soup.find(class_='data-na-objava').text.strip() if soup.find(class_='data-na-objava') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSdkNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find(class_='post-title entry-title').text.strip() if soup.find(class_='post-title entry-title') else None
  subtitle = soup.find(class_='post-title entry-title').text.strip() if soup.find(class_='post-title entry-title') else None
  date = soup.find("span", class_='value').text.strip() if soup.find("span", class_='value') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseFokusNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find(class_='post-title single-post-title entry-title').text.strip() if soup.find(class_='post-title single-post-title entry-title') else None
  subtitle = soup.find(class_='post-title single-post-title entry-title').text.strip() if soup.find(class_='post-title single-post-title entry-title') else None
  date = soup.find(class_='entry-date published').text.strip() if soup.find(class_='entry-date published') else None

  news_paragraphs = soup.find(class_="inner-post-entry entry-content").find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSport1News(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find(class_='title').text.strip() if soup.find(class_='title') else None
  subtitle = soup.find(class_='teaser field').text.strip() if soup.find(class_='teaser field') else None
  date = soup.find(class_='submitted').text.strip() if soup.find(class_='submitted') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseKanal5News(url, content):

  #Need to decode first from bytes to text
  html_content = content.decode("utf-8")
  soup = BeautifulSoup(html_content, 'html.parser')


  title = soup.find("h1", class_='article-title').text.strip() if soup.find("h1", class_='article-title') else None
  subtitle = soup.find(class_='subtitle').text.strip() if soup.find(class_='subtitle') else None
  date = soup.find(class_='article-published').text.strip() if soup.find(class_='article-published') else None
  main_content = soup.find(class_ = 'article-text').text.strip() if soup.find(class_ = 'article-text') else None

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseRepublikaNews(url, content):

  #Need to decode first from bytes to text
  html_content = content.decode("utf-8")
  soup = BeautifulSoup(html_content, 'html.parser')


  title = soup.find("h1", class_='title mb-3').text.strip() if soup.find("h1", class_='title mb-3') else None
  subtitle = soup.find("h1", class_='title mb-3').text.strip() if soup.find("h1", class_='title mb-3') else None
  date = soup.find("span", class_='date').text.strip() if soup.find("span", class_='date') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parsePuls24News(url, content):

  #Need to decode first from bytes to text
  html_content = content.decode("utf-8")
  soup = BeautifulSoup(html_content, 'html.parser')


  title = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  subtitle = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  date = soup.find(class_='entry-date updated published').text.strip() if soup.find(class_='entry-date updated published') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseMkdNews(url, content):

  #Need to decode first from bytes to text
  html_content = content.decode("utf-8")
  soup = BeautifulSoup(html_content, 'html.parser')


  title = soup.find("h1", class_='main-article-title').text.strip() if soup.find("h1", class_='main-article-title') else None
  subtitle = soup.find("div", id='podnaslov').text.strip() if soup.find("div", id='podnaslov') else None
  date = soup.find(class_='row mx-0 article-info mb-3').find("div").find("div").text.strip() if soup.find(class_='row mx-0 article-info mb-3').find("div").find("div") else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseAlsatNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='post-title entry-title').text.strip() if soup.find("h1", class_='post-title entry-title') else None
  subtitle = soup.find(class_='entry-sub-title').text.strip() if soup.find(class_='entry-sub-title') else None
  date = soup.find(class_='date meta-item tie-icon').text.strip() if soup.find(class_='date meta-item tie-icon') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSlobodnaEvropaNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='title pg-title').text.strip() if soup.find("h1", class_='title pg-title') else None
  subtitle = soup.find("h1", class_='title pg-title').text.strip() if soup.find("h1", class_='title pg-title') else None
  date = soup.find("time").text.strip() if soup.find("time") else None
  main_content = soup.find(class_="wsw").text.strip() if soup.find(class_="wsw") else None

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseMakfaksNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='mvp-post-title left entry-title').text.strip() if soup.find("h1", class_='mvp-post-title left entry-title') else None
  subtitle = soup.find("h1", class_='mvp-post-title left entry-title').text.strip() if soup.find("h1", class_='mvp-post-title left entry-title') else None
  date = soup.find(class_="post-date updated").text.strip() if soup.find(class_="post-date updated") else None

  news_paragraphs = soup.find(id="mvp-content-main").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseMkVoaNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='title pg-title').text.strip() if soup.find("h1", class_='title pg-title') else None
  subtitle = soup.find("h1", class_='title pg-title').text.strip() if soup.find("h1", class_='title pg-title') else None
  date = soup.find("time").text.strip() if soup.find("time") else None

  news_paragraphs = soup.find(class_="wsw").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseNetpressNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  subtitle = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  date = soup.find(class_="entry-date updated td-module-date").text.strip() if soup.find(class_="entry-date updated td-module-date") else None

  news_paragraphs = soup.find(class_="td-post-content").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSlobodenPecatNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='post-main-title').text.strip() if soup.find("h1", class_='post-main-title') else None
  subtitle = soup.find("h1", class_='post-main-title').text.strip() if soup.find("h1", class_='post-main-title') else None
  date = soup.find("time")["datetime"].strip() if soup.find("time") else None

  news_paragraphs = soup.find(class_="post-body-inner").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseMakpressNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')

  title = soup.find("div", class_='page-header').find("h1").text.strip() if soup.find("div", class_='page-header') else None
  subtitle = soup.find("div", class_='page-header').find("h1").text.strip() if soup.find("div", class_='page-header').find("h1") else None
  date = soup.find("div", class_="time").text.strip() if soup.find("div", class_="time") else None

  news_paragraphs = soup.find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseDWNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')

  title = soup.select_one(".content-area").find("header").find("h1").text.strip() if soup.select_one(".content-area").find("header").find("h1") else None
  subtitle = soup.select_one(".content-area").find("header").find("h1").text.strip() if soup.select_one(".content-area").find("header").find("h1") else None
  date = soup.find("time").text.strip() if soup.find("time") else None

  news_paragraphs = soup.select_one(".rich-text.has-italic").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parse24MkNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')

  title = soup.find(class_="post-title-area").find("h2", class_='post-title').text.strip() if soup.find(class_="post-title-area").find("h2", class_='post-title') else None
  subtitle = soup.find(class_="post-title-area").find("h2", class_='post-title').text.strip() if soup.find(class_="post-title-area").find("h2", class_='post-title') else None
  date = soup.find("span", class_="post-date").text.strip() if soup.find("span", class_="post-date") else None

  news_paragraphs = soup.find(class_="entry-content").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseRadioMofNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='post-title').text.strip() if soup.find("h1", class_='post-title') else None
  subtitle = soup.find("h1", class_='post-title').text.strip() if soup.find("h1", class_='post-title') else None
  date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

  news_paragraphs = soup.find(class_="post-content description").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseCentarMkNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='entry-title penci-entry-title penci-title-center').text.strip() if soup.find("h1", class_='entry-title penci-entry-title penci-title-center') else None
  subtitle = soup.find("h1", class_='entry-title penci-entry-title penci-title-center').text.strip() if soup.find("h1", class_='entry-title penci-entry-title penci-title-center') else None
  date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

  news_paragraphs = soup.find(class_="penci-entry-content entry-content").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseA1OnNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='entry-title penci-entry-title').text.strip() if soup.find("h1", class_='entry-title penci-entry-title') else None
  subtitle = soup.find("h1", class_='entry-title penci-entry-title').text.strip() if soup.find("h1", class_='entry-title penci-entry-title') else None
  date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

  news_paragraphs = soup.find(class_="penci-entry-content entry-content").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseTelmaNews(url, content):

    soup = BeautifulSoup(content, 'html.parser')
    title = soup.find(class_="entry-title penci-entry-title penci-title-").text.strip() if soup.find(class_="entry-title penci-entry-title penci-title-") else None
    subtitle = soup.find(class_="entry-title penci-entry-title penci-title-").text.strip() if soup.find(class_="entry-title penci-entry-title penci-title-") else None
    date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

    news_paragraphs = soup.find(class_="penci-entry-content entry-content").find_all("p")
    # Accumulate the text from all news paragraphs
    main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

    news_data = {
        'url' : url,
        'title': title,
        'subtitle': subtitle,
        'date': date,
        'main_content': main_content
    }
    
    return news_data

def parseEMagazinNews(url, content):

    soup = BeautifulSoup(content, 'html.parser')
    title = soup.find(class_="entry-title penci-entry-title penci-title-").text.strip() if soup.find(class_="entry-title penci-entry-title penci-title-") else None
    subtitle = soup.find(class_="entry-title penci-entry-title penci-title-").text.strip() if soup.find(class_="entry-title penci-entry-title penci-title-") else None
    date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

    news_paragraphs = soup.find(class_="penci-entry-content entry-content").find_all("p")
    # Accumulate the text from all news paragraphs
    main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

    news_data = {
        'url' : url,
        'title': title,
        'subtitle': subtitle,
        'date': date,
        'main_content': main_content
    }
    
    return news_data

# %%
from requests.exceptions import ConnectTimeout, ConnectionError
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
session = requests.Session()
retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])
adapter = HTTPAdapter(max_retries=retries)
session.mount('http://', adapter)
session.mount('https://', adapter)

successfully_accessed_sites = []
successfully_accessed_hostnames = []
unsuccessfully_accessed_sites = []

real_urls_list = []
parsedTexts = []

start_time = time.time()


for time_url in list_of_time_mk_urls:
    try:
          response = requests.get(time_url)
          # Gets the real url for each time.mk url.
          real_url = response.url
          real_urls_list.append(real_url)
          if response.status_code!=200:
                unsuccessfully_accessed_sites.append(real_url)
          else:
            successfully_accessed_sites.append(real_url)
            successfully_accessed_hostnames.append(urlparse(real_url).hostname)
            # Gets the html content for each response
            content = response.content
            # Gets the hostname for each url
            hostname = urlparse(real_url).hostname
            if hostname == "www.vecer.press":
                parsedTexts.append(parseVecerNews(real_url, content))
            elif hostname == "mk.tv21.tv":
                parsedTexts.append(parseTv21News(real_url, content))
            elif hostname == "360stepeni.mk":
                parsedTexts.append(parse360stepeni(real_url, content))
            elif hostname == "alfa.mk":
                parsedTexts.append(parseAlfaNews(real_url, content))
            elif hostname == "sitel.com.mk":
                parsedTexts.append(parseSitelNews(real_url, content))
            elif hostname == "sdk.mk":
                parsedTexts.append(parseSdkNews(real_url, content))
            elif hostname == "fokus.mk":
                parsedTexts.append(parseFokusNews(real_url, content))
            elif hostname == "sport1.mk":
                parsedTexts.append(parseSport1News(real_url, content))
            elif hostname == "kanal5.com.mk":
                parsedTexts.append(parseKanal5News(real_url, content))
            elif hostname == "republika.mk":
                parsedTexts.append(parseRepublikaNews(real_url, content))
            elif hostname == "puls24.mk":
                parsedTexts.append(parsePuls24News(real_url, content))
            elif hostname == "mkd.mk":
                parsedTexts.append(parseMkdNews(real_url, content))
            elif hostname == "novamakedonija.com.mk":
                parsedTexts.append(parseNovaMakedonijaNews(real_url, content))
            elif hostname == "alsat.mk":
                parsedTexts.append(parseAlsatNews(real_url, content))
            elif hostname == "www.slobodnaevropa.mk":
                parsedTexts.append(parseSlobodnaEvropaNews(real_url, content))
            elif hostname == "makfax.com.mk":
                parsedTexts.append(parseMakfaksNews(real_url, content))
            elif hostname == "mk.voanews.com":
                parsedTexts.append(parseMkVoaNews(real_url, content))
            elif hostname == "netpress.com.mk":
                parsedTexts.append(parseNetpressNews(real_url, content))
            elif hostname == "www.slobodenpecat.mk":
                parsedTexts.append(parseSlobodenPecatNews(real_url, content))
            elif hostname == "makpress.mk":
                parsedTexts.append(parseMakpressNews(real_url, content))
            elif hostname == "www.dw.com":
                parsedTexts.append(parseDWNews(real_url, content))
            elif hostname == "24.mk":
                parsedTexts.append(parse24MkNews(real_url, content))
            elif hostname == "www.radiomof.mk":
                parsedTexts.append(parseRadioMofNews(real_url, content))
            elif hostname == "centar.mk":
                parsedTexts.append(parseCentarMkNews(real_url, content))
            elif hostname == "a1on.mk":
                parsedTexts.append(parseA1OnNews(real_url, content))
            elif hostname == "telma.com.mk":
                parsedTexts.append(parseTelmaNews(real_url, content))
            elif hostname == "emagazin.mk":
                parsedTexts.append(parseEMagazinNews(real_url, content))
#             else:
#                 parsedTexts.append("Parse function for hostname " + hostname + " doesn't exist yet.")

    except (ConnectTimeout, ConnectionError) as e:
        print(f"Error connecting to {time_url}: {str(e)}")
        unsuccessfully_accessed_sites.append(time_url)
        continue
        
end_time = time.time()
total_time = end_time - start_time

print(f"The total time to parse all news sites is {total_time} seconds.")
# Out:
# The total time to parse all news sites is 176.2963569164276 seconds.

# %%
len(real_urls_list)
# Out:
# 60

# %%
print(successfully_accessed_sites)
print(successfully_accessed_hostnames)
print(unsuccessfully_accessed_sites)
# Out:
# ['https://24.mk/details/zaev-republika-severna-makedonija-kje-dobie-pretsedatel-koj-ne-e-zatalkan-patnik-tuku-vodach', 'https://kanal5.com.mk/articles/372931/siljanovska-davkova-loshata-politika-ne-mozhe-da-go-zgazi-pravoto', 'https://24.mk/details/znm-vmro-dpmne-da-se-izvini-za-etiketiranjeto-mediumi', 'https://24.mk/details/makedonija-vecherva-protiv-island-go-zaveruva-plasmanot-na-ep-2020', 'https://24.mk/details/akhmeti-pretsedatelot-vo-zaminuvanje-nema-legitimitet-da-gi-pomiluva-osudenite-za-krvaviot-chetvrtok', 'https://fokus.mk/sela-nie-nekogash-nema-da-poddrzhime-nekoj-koj-ne-e-kako-nas-i-ne-e-albanets/', 'https://smart.sdk.mk/stil/arhitektura/frantsija-ke-raspishe-megunaroden-konkurs-za-nova-kula-na-notr-dam/', 'https://24.mk/details/kiracovski-pendarovski-kje-ostvari-sigurna-pobeda-i-vo-vtoriot-izboren-krug', 'https://prizma.mk/pendarovski-i-siljanovska-so-tesna-razlika-odat-vo-vtor-krug-na-pretsedatelski-izbori/', 'https://prizma.mk/se-glasa-za-petiot-pretsedatel-na-shestite-direktni-izbori/', 'https://kanal5.com.mk/articles/373747/ochekuvanja-na-pretsedatelskite-kandidati', 'https://fokus.mk/dik-najmnogu-se-glasa-vo-prilep-i-sveti-nikole-a-najmalku-vo-bogovine-i-lipkovo/', 'https://kanal5.com.mk/articles/373762/redjepi-izborite-fer-i-demokratski-zagrizhuva-niskiot-oddziv', 'https://fokus.mk/siljanovska-do-bojkotirachite-doma-mozhev-da-ostanam-i-jas-no-odluchiv-da-se-boram/', 'https://www.mkd.mk/makedonija/politika/muhamed-zekiri-nie-za-zhal-sega-ja-plakjame-cenata-od-koaliciranjeto-so-dui', 'https://24.mk/details/koj-e-poglavar-na-islamskata-verska-zaednica', 'https://kanal5.com.mk/articles/374466/mickoski-ochekuvam-da-ima-cenzus-na-5-maj', 'https://24.mk/details/cenzusot-i-rezultatot-neizvesni-vo-vtoriot-krug-od-pretsedatelskite-izbori', 'https://kanal5.com.mk/articles/374485/siljanovska-davkova-mislam-deka-ovoj-den-e-i-specifichna-opomena-za-site-nas', 'https://irl.mk/severna-makedonija-dobiva-pretsedatel-vo-sdsm-narachaa-ketering/', 'https://prizma.mk/stevo-pendarovski-izbran-za-pretsedatel/', 'https://fokus.mk/siljanovska-inspirirav-poveke-gragani-da-izlezat-na-glasane-ochekuvam-pobeda/', 'https://www.mkd.mk/svet/analizi/politiko-balkanskiot-krah-na-makron', 'https://irl.mk/prvi-izavi-na-ministri-i-obichni-chlenovi-za-metlata-e-zborime-od-utre/', 'https://inovativnost.mk/2019/05/05/edna-%d1%82%d1%80%d0%b5%d1%82%d0%b8%d0%bd%d0%b0-%d0%be%d0%b4-%d0%bf%d0%be%d0%bf%d1%83%d0%bb%d0%b0%d1%86%d0%b8%d1%98%d0%b0%d1%82%d0%b0-%d0%bd%d0%b0-%d0%b7%d0%b0%d0%bf%d0%b0%d0%b4%d0%b5%d0%bd-%d0%b1/', 'https://kanal5.com.mk/articles/375718/biografija-na-noviot-pretsedatel-stevo-pendarovski', 'https://kanal5.com.mk/articles/375717/pendarovski-deneska-kje-bide-inauguriran-vo-sobranieto', 'https://kanal5.com.mk/articles/375618/memorijalna-velosipedska-tura-vo-chest-na-zaginatite-vo-divo-naselje', 'https://kanal5.com.mk/articles/375719/-vardar-pobednik-na-zavrshniot-rakometen-turnir-vo-pionerska-konkurencija-vo-delchevo', 'https://kanal5.com.mk/articles/375525/vlasta-i-opozicija-vo-nov-obid-da-se-dogovorot-za-idniot-status-na-sjo', 'https://makfax.com.mk/sport/ajaks-99-9-e-shampion-na-holandija-psv-kiksna-kaj-az-alkmar/', 'https://civilmedia.mk/chestitki-i-airlija-rabota-pretsedatele/', 'https://kanal5.com.mk/articles/375715/denovive-vrnezhi-od-preku-70-litri-na-metar-kvadraten', 'https://fokus.mk/tatkoto-na-tamara-tsela-vecher-ne-prestanav-da-placham-od-sreka/', 'https://fokus.mk/vmro-dpmne-ostavi-brashno-pred-sobranie-za-pavle-bogoevski/', 'https://netpress.com.mk/pendarovski-veke-gi-izbra-clenovite-na-negoviot-kabinet/', 'https://kanal5.com.mk/articles/376303/vo-apelacija-prodolzhi-sednicata-za-zhalbite-na-osudenite-za-divo-naselje', 'https://kanal5.com.mk/articles/376541/vmro-dpmne-filipche-e-celosno-nesposoben-za-vodenje-na-sektorot-na-zdravstvo', 'https://makfax.com.mk/sport/mizernata-sezona-za-real-zavrshi-mizerno-so-poraz-doma-od-betis-video/', 'https://kurir.mk/sport/fudbal/inzagi-kje-bide-noviot-trener-na-juventus/', 'https://ka ...
# ['24.mk', 'kanal5.com.mk', '24.mk', '24.mk', '24.mk', 'fokus.mk', 'smart.sdk.mk', '24.mk', 'prizma.mk', 'prizma.mk', 'kanal5.com.mk', 'fokus.mk', 'kanal5.com.mk', 'fokus.mk', 'www.mkd.mk', '24.mk', 'kanal5.com.mk', '24.mk', 'kanal5.com.mk', 'irl.mk', 'prizma.mk', 'fokus.mk', 'www.mkd.mk', 'irl.mk', 'inovativnost.mk', 'kanal5.com.mk', 'kanal5.com.mk', 'kanal5.com.mk', 'kanal5.com.mk', 'kanal5.com.mk', 'makfax.com.mk', 'civilmedia.mk', 'kanal5.com.mk', 'fokus.mk', 'fokus.mk', 'netpress.com.mk', 'kanal5.com.mk', 'kanal5.com.mk', 'makfax.com.mk', 'kurir.mk', 'kanal5.com.mk', 'makfax.com.mk']
# ['https://a1on.mk/archives/1039957', 'https://www.vecer.press/%D0%BA%D0%BE%D0%BB%D1%83%D0%BC%D0%BD%D0%B0-%D0%B8%D0%B1%D1%80%D0%B0%D1%85%D0%B8%D0%BC-%D0%B8%D0%B1%D1%80%D0%B0%D1%85%D0%B8%D0%BC%D0%B8-%D1%80%D0%BE%D0%BC%D0%B8%D1%82%D0%B5-%D0%BC%D0%B5%D1%93/', 'https://mk.tv21.tv/mk/pendarovski-siljanovska-davkova-nitu-saka-nitu-mozhe-da-bide-pretsedatel-taa-saka-da-bide-naslednik-na-ivanov/', 'https://mk.tv21.tv/mk/vmro-dpmne-zoran-zaev-i-stevo-pendarovski-se-vistinskiot-problem-za-makedonija/', 'https://www.alsat-m.tv/mk/%d0%b4%d0%b0%d0%b2%d0%ba%d0%be%d0%b2%d0%b0-%d0%b4%d0%b0-%d0%b3%d0%be-%d0%b4%d0%be%d0%ba%d0%b0%d0%b6%d0%b5%d0%bc%d0%b5-%d0%b5%d0%b2%d1%80%d0%be%d0%bf%d1%81%d0%ba%d0%b8%d0%be%d1%82-%d1%80%d0%b5%d1%84/', 'https://mk.tv21.tv/mk/mitskoski-graganite-treba-ednash-zasekogash-da-gi-porazat-nepravdite/', 'https://a1on.mk/archives/1043239', 'https://libertas.mk/partijata-za-demokratski-prosperitet-na-romite-so-poddrshka-za-pendarovski-vo-vtoriot-krug/', 'https://telma.com.mk/vernitsite-vo-shri-lanka-se-molat-vo-domovite-namesto-vo-tsrkvite/', 'https://www.alsat-m.tv/mk/%d1%84%d0%be%d0%ba%d1%83%d1%81%d0%be%d1%82-%d0%bd%d0%b0-%d0%b2%d1%82%d0%be%d1%80%d0%b8%d0%be%d1%82-%d0%b4%d0%b5%d0%bb-%d0%be%d0%b4-%d0%ba%d0%b0%d0%bc%d0%bf%d0%b0%d1%9a%d0%b0%d1%82%d0%b0-%d0%b5-%d0%ba/', 'https://mk.tv21.tv/mk/hristos-voskrese-pravoslavnite-hristijani-go-praznuvaat-veligden/', 'https://www.alsat-m.tv/mk/%d0%b2%d1%82%d0%be%d1%80%d0%b8%d0%be%d1%82-%d0%ba%d1%80%d1%83%d0%b3-%d0%b2%d0%be-%d1%82%d0%b5%d1%82%d0%be%d0%b2%d1%81%d0%ba%d0%be-%d1%81%d0%be-%d0%bf%d0%be%d0%bc%d0%b0%d0%bb%d0%b0-%d0%b8%d0%b7%d0%bb/', 'https://telma.com.mk/graganite-go-izbiraat-pettiot-pretsedatel-prv-na-republika-severna-makedonija/', 'https://mk.tv21.tv/mk/mitskoski-i-pokraj-site-nepravdi-i-nepravilnosti-ochekuvam-da-pobedime/', 'https://telma.com.mk/padna-voen-helikopter-vo-venetsuela-zaginaa-site-sedum-ofitseri/', 'https://libertas.mk/rasfati-ja-dnevnata/', 'https://mk.tv21.tv/mk/sdsm-zavrshi-mandatot-na-ivanov-prodolzhuvame-napred/', 'https://alfa.mk/%d0%b1%d0%b5%d0%ba%d1%82%d0%b5%d1%88%d0%b8-%d0%bd%d0%b5-%d1%81%d0%b5-%d0%b4%d0%b0%d0%b2%d0%b0-%d1%80%d0%b0%d0%b1%d0%be%d1%82%d0%b5%d0%bb-%d0%b4%d0%be%d0%b1%d1%80%d0%be-%d0%b8-%d0%bd%d0%b5-%d1%81/']

# %%
len(successfully_accessed_sites)
# Out:
# 42

# %%
len(parsedTexts)
# Out:
# 31

# %%
# parsedTexts

# %%
news_items = parsedTexts.copy()

# %%
for news_item in news_items:
    news_item['main_content'] = news_item['main_content'].replace('\n', '') if news_item['main_content'] != None else None
    news_item['main_content'] = news_item['main_content'].replace('\xa0', '') if news_item['main_content'] != None else None
    news_item['title'] = news_item['title'].replace('\xa0', '') if news_item['title'] != None else None
    news_item['subtitle'] = news_item['subtitle'].replace('\xa0', '') if news_item['subtitle'] != None else None

# %%
url_text_map = {}
for news_item in news_items:
  entry_url = news_item["url"]
  text = f"{news_item['title']}. {news_item['subtitle']}. {news_item['main_content']}"
  url_text_map[entry_url] = text

# %%
# !pip install transformers
# !pip install nlp
# !pip install sentencepiece
# !pip install torch
# !pip install spacy
# !pip install vaderSentiment
# !pip install textblob
# !pip install wordcloud matplotlib
# Out:
# Requirement already satisfied: transformers in c:\users\b5\anaconda3\lib\site-packages (4.32.0)
# Requirement already satisfied: filelock in c:\users\b5\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\b5\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\b5\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\b5\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: colorama in c:\users\b5\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b5\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b5\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b5\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b5\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: nlp in c:\users\b5\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: numpy in c:\users\b5\anaconda3\lib\site-packages (from nlp) (1.24.3)
# Requirement already satisfied: pyarrow>=0.16.0 in c:\users\b5\anaconda3\lib\site-packages (from nlp) (11.0.0)
# Requirement already satisfied: dill in c:\users\b5\anaconda3\lib\site-packages (from nlp) (0.3.6)
# Requirement already satisfied: pandas in c:\users\b5\anaconda3\lib\site-packages (from nlp) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\b5\anaconda3\lib\site-packages (from nlp) (2.31.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\b5\anaconda3\lib\site-packages (from nlp) (4.65.0)
# Requirement already satisfied: filelock in c:\users\b5\anaconda3\lib\site-packages (from nlp) (3.9.0)
# Requirement already satisfied: xxhash in c:\users\b5\anaconda3\lib\site-packages (from nlp) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b5\anaconda3\lib\site-packages (from requests>=2.19.0->nlp) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b5\anaconda3\lib\site-packages (from requests>=2.19.0->nlp) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b5\anaconda3\lib\site-packages (from requests>=2.19.0->nlp) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b5\anaconda3\lib\site-packages (from requests>=2.19.0->nlp) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\b5\anaconda3\lib\site-packages (from tqdm>=4.27->nlp) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\b5\anaconda3\lib\site-packages (from pandas->nlp) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\b5\anaconda3\lib\site-packages (from pandas->nlp) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\b5\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->nlp) (1.16.0)
# Requirement already satisfied: sentencepiece in c:\users\b5\anaconda3\lib\site-packages (0.1.99)
# Requirement already satisfied: torch in c:\users\b5\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: filelock in c:\users\b5\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\b5\anaconda3\lib\site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in c:\users\b5\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\b5\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\b5\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\b5\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\b5\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: spacy in c:\users\b5\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.3.0)
# Requirement already satisfied: jinja2 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\b5\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\b5\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\b5\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\b5\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b5\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b5\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b5\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b5\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\b5\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\b5\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.1)
# Requirement already satisfied: colorama in c:\users\b5\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\b5\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\b5\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: vaderSentiment in c:\users\b5\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\b5\anaconda3\lib\site-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b5\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b5\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b5\anaconda3\lib\site-packages (from requests->vaderSentiment) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b5\anaconda3\lib\site-packages (from requests->vaderSentiment) (2023.7.22)
# Requirement already satisfied: textblob in c:\users\b5\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\b5\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\b5\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\b5\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\b5\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\b5\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\b5\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Requirement already satisfied: wordcloud in c:\users\b5\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: matplotlib in c:\users\b5\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\b5\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\b5\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\b5\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !python -m spacy download en_core_web_sm

# %%
import transformers
import nlp
import torch
import spacy
from transformers import pipeline
from transformers import MarianMTModel, MarianTokenizer

import nltk
# nltk.download('punkt')

# %%
# Deprecated

# def chunk_text(text, tokenizer, max_length=1024):
#     # Split the text into sentences
#     sentences = nltk.sent_tokenize(text)
    
#     chunks = []
#     current_chunk = []
#     current_length = 0
    
#     for sentence in sentences:
#         # Tokenize the sentence to get its length
#         sentence_length = len(tokenizer.tokenize(sentence))
        
#         if current_length + sentence_length <= max_length:
#             current_chunk.append(sentence)
#             current_length += sentence_length
#         else:
#             chunks.append(" ".join(current_chunk))
#             current_chunk = [sentence]
#             current_length = sentence_length
    
#     if current_chunk:
#         chunks.append(" ".join(current_chunk))
    
#     return chunks

# %%
# # METHOD 1: Translate using MarianMT, A framework for translation models
# # Helsinki-NLP/opus-mt-mk-en

# # Load the pre-trained model and tokenizer
# model_name = "Helsinki-NLP/opus-mt-mk-en"
# model = MarianMTModel.from_pretrained(model_name)
# tokenizer = MarianTokenizer.from_pretrained(model_name)

# %%
# start_time = time.time()

# url_text_list = list(url_text_map.items())
# marian_translated_texts = {}
# for url_text in url_text_list[:1]:

#     # Define the input Macedonian text
    
#     input_url = url_text[0]
#     input_text = url_text[1]

#     # Split text into sentences using the Natural Language Toolkit Library
#     sentences = nltk.sent_tokenize(input_text)
    
#     # Translate each sentence separately
#     translated_sentences = []
#     for sentence in sentences:
#         input_ids = tokenizer.encode(sentence, return_tensors="pt")
#         with torch.no_grad():
#             translated_ids = model.generate(input_ids)
#         translated_sentence = tokenizer.decode(translated_ids[0], skip_special_tokens=True)
#         translated_sentences.append(translated_sentence)

#     # Combine translated sentences
#     translated_text = " ".join(translated_sentences)
#     marian_translated_texts[input_url] = translated_text
    
    
# end_time = time.time()
# total_time = end_time - start_time

# print(f"The total time to translate the text is {total_time} seconds.")

# %%
# marian_translated_texts

# %%
# !pip install googletrans==4.0.0rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0rc1 in c:\users\b5\anaconda3\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\b5\anaconda3\lib\site-packages (from googletrans==4.0.0rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2023.7.22)
# Requirement already satisfied: hstspreload in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2023.1.1)
# Requirement already satisfied: sniffio in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (1.2.0)
# Requirement already satisfied: chardet==3.* in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\b5\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\b5\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\b5\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\b5\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1) (3.0.0)

# %%
# METHOD 2: Translate using Google Translate API
from googletrans import Translator
import time
import random

# Time and random are so that google doesn't block my IP address because of a large number of requests

start_time = time.time()
url_text_list = list(url_text_map.items())
google_translated_texts = {}
translator = Translator()
for url_text in url_text_list:
    translated_text = translator.translate(url_text[1][:5000], src='mk', dest='en').text
    google_translated_texts[url_text[0]] = translated_text
    time.sleep(random.uniform(0.02, 0.1))

end_time = time.time()
total_time = end_time - start_time

print(f"The total time to translate the text is {total_time} seconds.")
# Out:
# The total time to translate the text is 15.20349645614624 seconds.

# %%
len(google_translated_texts)
# Out:
# 31

# %%
print(google_translated_texts)
# Out:
# {'https://24.mk/details/zaev-republika-severna-makedonija-kje-dobie-pretsedatel-koj-ne-e-zatalkan-patnik-tuku-vodach': 'Zaev: Republic of Northern Macedonia will receive a president who is not a stray passenger but a leader.Zaev: Republic of Northern Macedonia will receive a president who is not a stray passenger but a leader.In his address, SDSM leader and Prime Minister Zoran Zaev said "The time of criminals and crime protectors ended".- The Republic of Northern Macedonia will receive a president for whom the future of the state is not an adventure, but a duty, and he is not a stray passenger but a leader.We defeated divisions, hatred, conflicts and unrest.Europe applauds, and citizens want our policy to move forward.The new president will be a man who wants, can and must pull forward - that is Stevo Pendarovski, Zaev said at the central rally in the capital.We are already, said the SDSM leader, part of NATO and by the end of the year we will be an equal member."We go to the EU and expect, he stressed, to value reforms at home and good neighborly relations and this summer to get a date for start of negotiations we are seriously preparing.- The wind of changes has been blowing for two years.Since we have decided to direct the helm of our common ship together, regardless of any difference, we have come together, we have united, we move forward.There is no stop.We go ahead with Stevo Pendarovski.It was not easy, but we united against the regime.We decided and started building a society for everyone.We sat down with our neighbors and solved the most difficult questions.We went into serious reforms and established a rule of law, a chance for everyone.It wasn\'t easy.Our common successes are a balm of our wounds from the dark past.And no one, but no one, will not be able to let us go back, Zaev said.The leader of SDSM and prime minister, speaking of the successes in the economy, said that the wind would be further strengthened for those numbers to become twice as high as to feel the people.It promised over 500 euros in average salary in 2020.In criticism from the opposition, Zaev responded that the identity was preserved and "cluttered", that we were, as he said, proud Macedonians speaking Macedonian language recognized around the world.Make comparisons with the other two candidates - Blerim Reka said he is not a joint candidate for all citizens, but one ethnic community, and Pendarovski is supported by 31 party, of all ethnic communities and political commitments.Siljanovska-Davkova, meanwhile, said that it is not for a society for everyone, that it is not a joint candidate, but "only one man representative-Mickoski, who is a representative of the criminal Gruevski".-Stevo is a civic candidate, a man with integrity, a fighter for justice. With whom in NATO and the EU, if not with a man who unites and drags forward in prosperity, not back in the dark past.Stevo Pendarovski is a development, Gordana Siljanovska is a stall.It is not the solution to the problem - the brake Gjorge Ivanov, but a new problem.She sells false morals, Zaev said and asked why how the minister in the 1990s did not do anything with the transition he was talking about and why they left this government to solve the problem with 10,000 bankruptcies.In his address, Zaev urged Mickoski to publicly deny himself from the politics of his predecessor Nikola Gruevski because, he said, "We did not hear from Mickoski and Siljanovska for 11 years of rule for the mentor Gruevski".', 'https://kanal5.com.mk/articles/372931/siljanovska-davkova-loshata-politika-ne-mozhe-da-go-zgazi-pravoto': 'Siljanovska-Davkova: Bad politics cannot break the right.VMRO-DPMNE-backed presidential candidate Gordana Siljanovska Davkova addressed a rally in Sveti Nikole this afternoon.Siljanovska Davkova said that without the rule of law and justice, without a battle with crime and corruption, a battle with nepotism, improved health system and quality education we would find it difficult to get a  ...

# %%
# # METHOD 3: Translate using distilled version of the  Facebook Neural Language Model for Low-Resource Languages (NLLB-200)
# from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M", src_lang="mk_Cyrl")
# model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

# %%
# start_time = time.time()


# url_text_list = list(url_text_map.items())
# nllb_translated_texts = {}
# for url_text in url_text_list[:1]:
    
#     # Define the input Macedonian text
    
#     input_url = url_text[0]
#     input_text = url_text[1]
    
#     sentences = nltk.sent_tokenize(input_text)

#     translated_sentences = []
#     for sentence in sentences:
#         inputs = tokenizer(sentence, return_tensors="pt")
#         translated_tokens = model.generate(
#         **inputs, forced_bos_token_id=tokenizer.lang_code_to_id["eng_Latn"]
#         )
#         translated_sentence = tokenizer.decode(translated_tokens[0], skip_special_tokens=True)
#         translated_sentences.append(translated_sentence)
    
#     # Combine translated sentences
#     translated_text = " ".join(translated_sentences)
#     nllb_translated_texts[input_url] = translated_text
    
# end_time = time.time()
# total_time = end_time - start_time

# print(f"The total time to translate the text is {total_time} seconds.")

# %%
# nllb_translated_texts

# %%
# CONTINUE USING ONLY GOOGLE TRANSLATED TEXTS FOR BEST ACCURACY

# %%
# Function to aggregate the sentiment for a single entity, since a single entity will have multiple sentiments
# if the entity is present in multiple sentences.
# sentiments contains a list of all the sentiments for a single entity that were gathered from the text

def aggregate_sentiment(sentiments):
    # Initialize counters
    total_positive = 0
    total_negative = 0
    count_positive = 0
    count_negative = 0
    
    for sentiment in sentiments:
        if sentiment['label'] == 'POSITIVE':
            total_positive += sentiment['score']
            count_positive += 1
        elif sentiment['label'] == 'NEGATIVE':
            total_negative += sentiment['score']
            count_negative += 1
            
    # Calculate averages
    avg_positive = total_positive / count_positive if count_positive != 0 else 0
    avg_negative = total_negative / count_negative if count_negative != 0 else 0


    if total_positive > total_negative:
        return {'label': 'POSITIVE', 'score': avg_positive, 'total_positive': total_positive, 'total_negative': total_negative, 'count_positive': count_positive, 'count_negative': count_negative}
    else:
        return {'label': 'NEGATIVE', 'score': avg_negative, 'total_positive': total_positive, 'total_negative': total_negative, 'count_positive': count_positive, 'count_negative': count_negative}

# %%
# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Define sentiment analysis pipeline using transformers
# sentiment_pipeline = pipeline("sentiment-analysis", model="siebert/sentiment-roberta-large-english")
sentiment_pipeline = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")

# Extracts entities and sentiment for a single text
def extract_entities_and_sentiment(text):
    doc = nlp(text)
    
    # Store entity sentiments
    entity_sentiments = {}
    # Store sentences for each entity
    entity_sentences = {}
    # map of entity, list of sentences that contain entity
    for ent in doc.ents:
        if ent.text not in entity_sentences:
            entity_sentences[ent.text] = [ent.sent.text]
        else:
            entity_sentences[ent.text].append(ent.sent.text)
            
    for entity, sentences in entity_sentences.items():
        sentiments = []
        for sentence in sentences:
            sentiment = sentiment_pipeline(sentence)
            sentiments.append(sentiment[0])
        
    
        entity_sentiments[entity] = aggregate_sentiment(sentiments)

    return entity_sentiments

# %%
entity_sentiments = []
google_translated_texts_list = list(google_translated_texts.items())
url_sentiments = []
for url_translated_text in google_translated_texts_list:
    entity_sentiments = extract_entities_and_sentiment(url_translated_text[1])
    url_sentiments.append([url_translated_text[0], entity_sentiments])

# %%
url_sentiments
# Out:
# [['https://24.mk/details/zaev-republika-severna-makedonija-kje-dobie-pretsedatel-koj-ne-e-zatalkan-patnik-tuku-vodach',
#   {'Zaev': {'label': 'NEGATIVE',
#     'score': 0.9454014450311661,
#     'total_positive': 2.9939094185829163,
#     'total_negative': 3.7816057801246643,
#     'count_positive': 3,
#     'count_negative': 4},
#    'SDSM': {'label': 'POSITIVE',
#     'score': 0.9980232417583466,
#     'total_positive': 1.9960464835166931,
#     'total_negative': 0.918300211429596,
#     'count_positive': 2,
#     'count_negative': 1},
#    'Zoran Zaev': {'label': 'NEGATIVE',
#     'score': 0.918300211429596,
#     'total_positive': 0,
#     'total_negative': 0.918300211429596,
#     'count_positive': 0,
#     'count_negative': 1},
#    'The Republic of Northern Macedonia': {'label': 'POSITIVE',
#     'score': 0.9984772801399231,
#     'total_positive': 0.9984772801399231,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Europe': {'label': 'POSITIVE',
#     'score': 0.9989223480224609,
#     'total_positive': 0.9989223480224609,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Stevo Pendarovski': {'label': 'POSITIVE',
#     'score': 0.9980781972408295,
#     'total_positive': 1.996156394481659,
#     'total_negative': 0.9981518387794495,
#     'count_positive': 2,
#     'count_negative': 1},
#    'NATO': {'label': 'POSITIVE',
#     'score': 0.9980853497982025,
#     'total_positive': 1.996170699596405,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'the end of the year': {'label': 'POSITIVE',
#     'score': 0.9995054006576538,
#     'total_positive': 0.9995054006576538,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'EU': {'label': 'POSITIVE',
#     'score': 0.9974488615989685,
#     'total_positive': 1.994897723197937,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'this summer': {'label': 'POSITIVE',
#     'score': 0.9982324242591858,
#     'total_positive': 0.9982324242591858,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'two years': {'label': 'NEGATIVE',
#     'score': 0.9314896464347839,
#     'total_positive': 0,
#     'total_negative': 0.9314896464347839,
#     'count_positive': 0,
#     'count_negative': 1},
#    '500': {'label': 'NEGATIVE',
#     'score': 0.9956507086753845,
#     'total_positive': 0,
#     'total_negative': 0.9956507086753845,
#     'count_positive': 0,
#     'count_negative': 1},
#    '2020.In': {'label': 'NEGATIVE',
#     'score': 0.9956507086753845,
#     'total_positive': 0,
#     'total_negative': 0.9956507086753845,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Macedonians': {'label': 'NEGATIVE',
#     'score': 0.9956507086753845,
#     'total_positive': 0,
#     'total_negative': 0.9956507086753845,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Macedonian': {'label': 'NEGATIVE',
#     'score': 0.9956507086753845,
#     'total_positive': 0,
#     'total_negative': 0.9956507086753845,
#     'count_positive': 0,
#     'count_negative': 1},
#    'two': {'label': 'POSITIVE',
#     'score': 0.991877555847168,
#     'total_positive': 0.991877555847168,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'one': {'label': 'POSITIVE',
#     'score': 0.991877555847168,
#     'total_positive': 0.991877555847168,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Pendarovski': {'label': 'POSITIVE',
#     'score': 0.991877555847168,
#     'total_positive': 0.991877555847168,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '31 party': {'label': 'POSITIVE',
#     'score': 0.991877555847168,
#     'total_positive': 0.991877555847168,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Siljanovska': {'label': 'NEGATIVE',
#     'score': 0.8829853236675262,
#     'total_positive': 0,
#     'total_negative': 1.7659706473350525,
#     'count_positive': 0,
#     'count_negative': 2},
#    'only one': {'label': 'NEGATIVE',
#     'score': 0.8018938302993774,
#     'total_positive': 0,
#     'total_negative': 0.8018938302993774,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gruevski".-Stevo': {'label': 'NEGATIVE',
#     'score': 0.8018938302993774,
#     'total_positive': 0,
#     'total_negative': 0.8018938302993774,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gordana Siljanovska': {'label': 'NEGATIVE',
#     'score': 0.9981518387794495,
#     'total_positive': 0,
#     'total_negative': 0.9981518387794495,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gjorge Ivanov': {'label': 'NEGATIVE',
#     'score': 0.9988002777099609,
#     'total_positive': 0,
#     'total_negative': 0.9988002777099609,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the 1990s': {'label': 'NEGATIVE',
#     'score': 0.9979903697967529,
#     'total_positive': 0,
#     'total_negative': 0.9979903697967529,
#     'count_positive': 0,
#     'count_negative': 1},
#    '10,000': {'label': 'NEGATIVE',
#     'score': 0.9979903697967529,
#     'total_positive': 0,
#     'total_negative': 0.9979903697967529,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Mickoski': {'label': 'NEGATIVE',
#     'score': 0.964076817035675,
#     'total_positive': 0,
#     'total_negative': 1.92815363407135,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Nikola Gruevski': {'label': 'NEGATIVE',
#     'score': 0.964076817035675,
#     'total_positive': 0,
#     'total_negative': 0.964076817035675,
#     'count_positive': 0,
#     'count_negative': 1},
#    '11 years': {'label': 'NEGATIVE',
#     'score': 0.964076817035675,
#     'total_positive': 0,
#     'total_negative': 0.964076817035675,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gruevski': {'label': 'NEGATIVE',
#     'score': 0.964076817035675,
#     'total_positive': 0,
#     'total_negative': 0.964076817035675,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://kanal5.com.mk/articles/372931/siljanovska-davkova-loshata-politika-ne-mozhe-da-go-zgazi-pravoto',
#   {'Siljanovska': {'label': 'NEGATIVE',
#     'score': 0.9445458054542542,
#     'total_positive': 0.984331488609314,
#     'total_negative': 2.8336374163627625,
#     'count_positive': 1,
#     'count_negative': 3},
#    'Gordana Siljanovska': {'label': 'NEGATIVE',
#     'score': 0.5937113165855408,
#     'total_positive': 0,
#     'total_negative': 0.5937113165855408,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Davkova': {'label': 'NEGATIVE',
#     'score': 0.5937113165855408,
#     'total_positive': 0,
#     'total_negative': 0.5937113165855408,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Sveti Nikole': {'label': 'NEGATIVE',
#     'score': 0.8101482192675272,
#     'total_positive': 0,
#     'total_negative': 2.430444657802582,
#     'count_positive': 0,
#     'count_negative': 3},
#    'this afternoon': {'label': 'NEGATIVE',
#     'score': 0.5937113165855408,
#     'total_positive': 0,
#     'total_negative': 0.5937113165855408,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Siljanovska Davkova': {'label': 'NEGATIVE',
#     'score': 0.9474264979362488,
#     'total_positive': 0,
#     'total_negative': 1.8948529958724976,
#     'count_positive': 0,
#     'count_negative': 2},
#    'EU': {'label': 'NEGATIVE',
#     'score': 0.8806277513504028,
#     'total_positive': 0,
#     'total_negative': 1.7612555027008057,
#     'count_positive': 0,
#     'count_negative': 2},
#    "VMRO-DPMNE's": {'label': 'NEGATIVE',
#     'score': 0.8651218414306641,
#     'total_positive': 0,
#     'total_negative': 0.8651218414306641,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gordana': {'label': 'NEGATIVE',
#     'score': 0.8651218414306641,
#     'total_positive': 0,
#     'total_negative': 0.8651218414306641,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Davkovska': {'label': 'NEGATIVE',
#     'score': 0.8651218414306641,
#     'total_positive': 0,
#     'total_negative': 0.8651218414306641,
#     'count_positive': 0,
#     'count_negative': 1},
#    'This afternoon': {'label': 'NEGATIVE',
#     'score': 0.8651218414306641,
#     'total_positive': 0,
#     'total_negative': 0.8651218414306641,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the past two and a half years': {'label': 'POSITIVE',
#     'score': 0.9958668947219849,
#     'total_positive': 0.9958668947219849,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'April 21': {'label': 'POSITIVE',
#     'score': 0.9958668947219849,
#     'total_positive': 0.9958668947219849,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'European': {'label': 'NEGATIVE',
#     'score': 0.971611499786377,
#     'total_positive': 0,
#     'total_negative': 0.971611499786377,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Veles': {'label': 'POSITIVE',
#     'score': 0.984331488609314,
#     'total_positive': 0.984331488609314,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'tonight': {'label': 'POSITIVE',
#     'score': 0.984331488609314,
#     'total_positive': 0.984331488609314,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://24.mk/details/znm-vmro-dpmne-da-se-izvini-za-etiketiranjeto-mediumi',
#   {'AJM': {'label': 'NEGATIVE',
#     'score': 0.9986355900764465,
#     'total_positive': 0,
#     'total_negative': 2.9959067702293396,
#     'count_positive': 0,
#     'count_negative': 3},
#    'The Association of Journalists of Macedonia': {'label': 'NEGATIVE',
#     'score': 0.9994200468063354,
#     'total_positive': 0,
#     'total_negative': 0.9994200468063354,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Christian Mickoski': {'label': 'NEGATIVE',
#     'score': 0.9994200468063354,
#     'total_positive': 0,
#     'total_negative': 0.9994200468063354,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Krusevo': {'label': 'NEGATIVE',
#     'score': 0.9994200468063354,
#     'total_positive': 0,
#     'total_negative': 1.998840093612671,
#     'count_positive': 0,
#     'count_negative': 2},
#    'SDSM': {'label': 'NEGATIVE',
#     'score': 0.9994200468063354,
#     'total_positive': 0,
#     'total_negative': 0.9994200468063354,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Mickoski': {'label': 'NEGATIVE',
#     'score': 0.9643383622169495,
#     'total_positive': 0,
#     'total_negative': 0.9643383622169495,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Telma TV': {'label': 'NEGATIVE',
#     'score': 0.9643383622169495,
#     'total_positive': 0,
#     'total_negative': 0.9643383622169495,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://24.mk/details/makedonija-vecherva-protiv-island-go-zaveruva-plasmanot-na-ep-2020',
#   {'Macedonia': {'label': 'POSITIVE',
#     'score': 0.9868908375501633,
#     'total_positive': 3.947563350200653,
#     'total_negative': 0,
#     'count_positive': 4,
#     'count_negative': 0},
#    'tonight': {'label': 'POSITIVE',
#     'score': 0.9869139790534973,
#     'total_positive': 3.9476559162139893,
#     'total_negative': 0,
#     'count_positive': 4,
#     'count_negative': 0},
#    'Iceland': {'label': 'POSITIVE',
#     'score': 0.9868908375501633,
#     'total_positive': 3.947563350200653,
#     'total_negative': 0,
#     'count_positive': 4,
#     'count_negative': 0},
#    'Euro 2020': {'label': 'POSITIVE',
#     'score': 0.9953758120536804,
#     'total_positive': 1.9907516241073608,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    '20:00.in': {'label': 'POSITIVE',
#     'score': 0.9571391940116882,
#     'total_positive': 0.9571391940116882,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Euro 2020': {'label': 'POSITIVE',
#     'score': 0.9571391940116882,
#     'total_positive': 0.9571391940116882,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Reykjavik': {'label': 'POSITIVE',
#     'score': 0.999672532081604,
#     'total_positive': 0.999672532081604,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '34:33': {'label': 'POSITIVE',
#     'score': 0.999672532081604,
#     'total_positive': 0.999672532081604,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'first': {'label': 'POSITIVE',
#     'score': 0.911969393491745,
#     'total_positive': 1.82393878698349,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'third': {'label': 'POSITIVE',
#     'score': 0.999672532081604,
#     'total_positive': 0.999672532081604,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'EP': {'label': 'POSITIVE',
#     'score': 0.9997650980949402,
#     'total_positive': 0.9997650980949402,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Danilo Brestovac': {'label': 'POSITIVE',
#     'score': 0.824266254901886,
#     'total_positive': 0.824266254901886,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Dimitrioski': {'label': 'POSITIVE',
#     'score': 0.9976053237915039,
#     'total_positive': 0.9976053237915039,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Martin Serafimov': {'label': 'POSITIVE',
#     'score': 0.9976053237915039,
#     'total_positive': 0.9976053237915039,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Bojan Madzovski': {'label': 'POSITIVE',
#     'score': 0.9976053237915039,
#     'total_positive': 0.9976053237915039,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Tomislav Jagurinovski': {'label': 'POSITIVE',
#     'score': 0.9976053237915039,
#     'total_positive': 0.9976053237915039,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://24.mk/details/akhmeti-pretsedatelot-vo-zaminuvanje-nema-legitimitet-da-gi-pomiluva-osudenite-za-krvaviot-chetvrtok',
#   {'Ahmeti -': {'label': 'POSITIVE',
#     'score': 0.9955540299415588,
#     'total_positive': 0.9955540299415588,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'DUI': {'label': 'NEGATIVE',
#     'score': 0.9979580640792847,
#     'total_positive': 0,
#     'total_negative': 0.9979580640792847,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Thursday': {'label': 'NEGATIVE',
#     'score': 0.9979580640792847,
#     'total_positive': 0,
#     'total_negative': 0.9979580640792847,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Ali Ahmeti': {'label': 'NEGATIVE',
#     'score': 0.999140739440918,
#     'total_positive': 0,
#     'total_negative': 0.999140739440918,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gjorge Ivanov': {'label': 'NEGATIVE',
#     'score': 0.999140739440918,
#     'total_positive': 0,
#     'total_negative': 0.999140739440918,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Ivanov': {'label': 'NEGATIVE',
#     'score': 0.9929629365603129,
#     'total_positive': 0.9902040958404541,
#     'total_negative': 2.9788888096809387,
#     'count_positive': 1,
#     'count_negative': 3},
#    'Ahmeti': {'label': 'NEGATIVE',
#     'score': 0.9314847588539124,
#     'total_positive': 0,
#     'total_negative': 0.9314847588539124,
#     'count_positive': 0,
#     'count_negative': 1},
#    'more than a week': {'label': 'NEGATIVE',
#     'score': 0.992236316204071,
#     'total_positive': 0,
#     'total_negative': 0.992236316204071,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Dobrila Kacarska': {'label': 'NEGATIVE',
#     'score': 0.7507288455963135,
#     'total_positive': 0,
#     'total_negative': 0.7507288455963135,
#     'count_positive': 0,
#     'count_negative': 1},
#    '211 years': {'label': 'NEGATIVE',
#     'score': 0.7507288455963135,
#     'total_positive': 0,
#     'total_negative': 0.7507288455963135,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Amnesty Law': {'label': 'POSITIVE',
#     'score': 0.9902040958404541,
#     'total_positive': 0.9902040958404541,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Amnesty': {'label': 'NEGATIVE',
#     'score': 0.9941495656967163,
#     'total_positive': 0,
#     'total_negative': 0.9941495656967163,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Assembly': {'label': 'NEGATIVE',
#     'score': 0.9941495656967163,
#     'total_positive': 0,
#     'total_negative': 0.9941495656967163,
#     'count_positive': 0,
#     'count_negative': 1},
#    'John Ioannidis': {'label': 'NEGATIVE',
#     'score': 0.9952614903450012,
#     'total_positive': 0,
#     'total_negative': 0.9952614903450012,
#     'count_positive': 0,
#     'count_negative': 1},
#    '2016': {'label': 'NEGATIVE',
#     'score': 0.9920716881752014,
#     'total_positive': 0,
#     'total_negative': 0.9920716881752014,
#     'count_positive': 0,
#     'count_negative': 1},
#    '56': {'label': 'NEGATIVE',
#     'score': 0.9920716881752014,
#     'total_positive': 0,
#     'total_negative': 0.9920716881752014,
#     'count_positive': 0,
#     'count_negative': 1},
#    'SPO': {'label': 'NEGATIVE',
#     'score': 0.9920716881752014,
#     'total_positive': 0,
#     'total_negative': 0.9920716881752014,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Antocorruption': {'label': 'NEGATIVE',
#     'score': 0.9986510872840881,
#     'total_positive': 0,
#     'total_negative': 0.9986510872840881,
#     'count_positive': 0,
#     'count_negative': 1},
#    'two': {'label': 'NEGATIVE',
#     'score': 0.9977684020996094,
#     'total_positive': 0,
#     'total_negative': 1.9955368041992188,
#     'count_positive': 0,
#     'count_negative': 2},
#    'about 250,000': {'label': 'NEGATIVE',
#     'score': 0.9986510872840881,
#     'total_positive': 0,
#     'total_negative': 0.9986510872840881,
#     'count_positive': 0,
#     'count_negative': 1},
#    "Villa Vodno's": {'label': 'NEGATIVE',
#     'score': 0.9968857169151306,
#     'total_positive': 0,
#     'total_negative': 0.9968857169151306,
#     'count_positive': 0,
#     'count_negative': 1},
#    'about 100,000': {'label': 'NEGATIVE',
#     'score': 0.949797511100769,
#     'total_positive': 0,
#     'total_negative': 0.949797511100769,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://fokus.mk/sela-nie-nekogash-nema-da-poddrzhime-nekoj-koj-ne-e-kako-nas-i-ne-e-albanets/',
#   {'Albanian': {'label': 'NEGATIVE',
#     'score': 0.9983294208844503,
#     'total_positive': 0,
#     'total_negative': 2.994988262653351,
#     'count_positive': 0,
#     'count_negative': 3},
#    'Blerim River': {'label': 'POSITIVE',
#     'score': 0.7766283750534058,
#     'total_positive': 0.7766283750534058,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'tonight': {'label': 'POSITIVE',
#     'score': 0.7766283750534058,
#     'total_positive': 0.7766283750534058,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Tetovo': {'label': 'POSITIVE',
#     'score': 0.7766283750534058,
#     'total_positive': 0.7766283750534058,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Zelino': {'label': 'POSITIVE',
#     'score': 0.8666194677352905,
#     'total_positive': 1.733238935470581,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'April 21.He': {'label': 'POSITIVE',
#     'score': 0.7766283750534058,
#     'total_positive': 0.7766283750534058,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'EU': {'label': 'NEGATIVE',
#     'score': 0.9969022274017334,
#     'total_positive': 0,
#     'total_negative': 0.9969022274017334,
#     'count_positive': 0,
#     'count_negative': 1},
#    'NATO': {'label': 'NEGATIVE',
#     'score': 0.9969022274017334,
#     'total_positive': 0,
#     'total_negative': 0.9969022274017334,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Albanians': {'label': 'NEGATIVE',
#     'score': 0.9983812769254049,
#     'total_positive': 0.9450190663337708,
#     'total_negative': 2.9951438307762146,
#     'count_positive': 1,
#     'count_negative': 3},
#    'the Alliance of Albanians Ziadin Sela': {'label': 'NEGATIVE',
#     'score': 0.9977193474769592,
#     'total_positive': 0,
#     'total_negative': 0.9977193474769592,
#     'count_positive': 0,
#     'count_negative': 1},
#    'SDSM': {'label': 'NEGATIVE',
#     'score': 0.9977193474769592,
#     'total_positive': 0,
#     'total_negative': 0.9977193474769592,
#     'count_positive': 0,
#     'count_negative': 1},
#    '18 years': {'label': 'NEGATIVE',
#     'score': 0.9977193474769592,
#     'total_positive': 0,
#     'total_negative': 0.9977193474769592,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Sela': {'label': 'NEGATIVE',
#     'score': 0.9973649382591248,
#     'total_positive': 0,
#     'total_negative': 0.9973649382591248,
#     'count_positive': 0,
#     'count_negative': 1},
#    'BESA': {'label': 'POSITIVE',
#     'score': 0.9566105604171753,
#     'total_positive': 0.9566105604171753,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Bilal Kasami': {'label': 'POSITIVE',
#     'score': 0.9566105604171753,
#     'total_positive': 0.9566105604171753,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '2014': {'label': 'NEGATIVE',
#     'score': 0.8494495153427124,
#     'total_positive': 0,
#     'total_negative': 0.8494495153427124,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kasami': {'label': 'NEGATIVE',
#     'score': 0.8494495153427124,
#     'total_positive': 0,
#     'total_negative': 0.8494495153427124,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Zelino, Blerim Sejdiu': {'label': 'POSITIVE',
#     'score': 0.984954833984375,
#     'total_positive': 0.984954833984375,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://24.mk/details/kiracovski-pendarovski-kje-ostvari-sigurna-pobeda-i-vo-vtoriot-izboren-krug',
#   {'Kiracovski': {'label': 'POSITIVE',
#     'score': 0.978367805480957,
#     'total_positive': 0.978367805480957,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'second': {'label': 'POSITIVE',
#     'score': 0.9997391104698181,
#     'total_positive': 1.9994782209396362,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'SDSM': {'label': 'NEGATIVE',
#     'score': 0.73466956615448,
#     'total_positive': 0,
#     'total_negative': 0.73466956615448,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Stevo Pendarovski': {'label': 'POSITIVE',
#     'score': 0.998126208782196,
#     'total_positive': 0.998126208782196,
#     'total_negative': 0.73466956615448,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Gordana': {'label': 'POSITIVE',
#     'score': 0.9850356578826904,
#     'total_positive': 0.9850356578826904,
#     'total_negative': 0.73466956615448,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Siljanovska Davkova': {'label': 'POSITIVE',
#     'score': 0.9850356578826904,
#     'total_positive': 0.9850356578826904,
#     'total_negative': 0.73466956615448,
#     'count_positive': 1,
#     'count_negative': 1},
#    'about two-thirds': {'label': 'NEGATIVE',
#     'score': 0.73466956615448,
#     'total_positive': 0,
#     'total_negative': 0.73466956615448,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Pendarovski': {'label': 'POSITIVE',
#     'score': 0.9850356578826904,
#     'total_positive': 0.9850356578826904,
#     'total_negative': 0.73466956615448,
#     'count_positive': 1,
#     'count_negative': 1},
#    '2.5 percent': {'label': 'POSITIVE',
#     'score': 0.9850356578826904,
#     'total_positive': 0.9850356578826904,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Northern Macedonia': {'label': 'POSITIVE',
#     'score': 0.998126208782196,
#     'total_positive': 0.998126208782196,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://kanal5.com.mk/articles/373747/ochekuvanja-na-pretsedatelskite-kandidati',
#   {'Stevo Pendarovski': {'label': 'NEGATIVE',
#     'score': 0.9158827066421509,
#     'total_positive': 0,
#     'total_negative': 0.9158827066421509,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gordana': {'label': 'NEGATIVE',
#     'score': 0.9158827066421509,
#     'total_positive': 0,
#     'total_negative': 0.9158827066421509,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Siljanovska Davkova': {'label': 'NEGATIVE',
#     'score': 0.9158827066421509,
#     'total_positive': 0,
#     'total_negative': 0.9158827066421509,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Blerim River': {'label': 'NEGATIVE',
#     'score': 0.9158827066421509,
#     'total_positive': 0,
#     'total_negative': 0.9158827066421509,
#     'count_positive': 0,
#     'count_negative': 1},
#    'today': {'label': 'POSITIVE',
#     'score': 0.9943168759346008,
#     'total_positive': 0.9943168759346008,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Euro': {'label': 'POSITIVE',
#     'score': 0.9943168759346008,
#     'total_positive': 0.9943168759346008,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'NATO': {'label': 'POSITIVE',
#     'score': 0.9943168759346008,
#     'total_positive': 0.9943168759346008,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://fokus.mk/dik-najmnogu-se-glasa-vo-prilep-i-sveti-nikole-a-najmalku-vo-bogovine-i-lipkovo/',
#   {'SEC': {'label': 'NEGATIVE',
#     'score': 0.8482911586761475,
#     'total_positive': 0,
#     'total_negative': 1.696582317352295,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Prilep': {'label': 'POSITIVE',
#     'score': 0.9677905837694804,
#     'total_positive': 2.903371751308441,
#     'total_negative': 0,
#     'count_positive': 3,
#     'count_negative': 0},
#    'Sveti Nikole': {'label': 'POSITIVE',
#     'score': 0.9677905837694804,
#     'total_positive': 2.903371751308441,
#     'total_negative': 0,
#     'count_positive': 3,
#     'count_negative': 0},
#    'Bogovinje': {'label': 'POSITIVE',
#     'score': 0.9963425993919373,
#     'total_positive': 1.9926851987838745,
#     'total_negative': 1.9926453828811646,
#     'count_positive': 2,
#     'count_negative': 2},
#    'Lipkovo': {'label': 'POSITIVE',
#     'score': 0.9963425993919373,
#     'total_positive': 1.9926851987838745,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'The State Election Commission': {'label': 'NEGATIVE',
#     'score': 0.9747686982154846,
#     'total_positive': 0,
#     'total_negative': 0.9747686982154846,
#     'count_positive': 0,
#     'count_negative': 1},
#    'first': {'label': 'NEGATIVE',
#     'score': 0.9747686982154846,
#     'total_positive': 0,
#     'total_negative': 0.9747686982154846,
#     'count_positive': 0,
#     'count_negative': 1},
#    'one': {'label': 'NEGATIVE',
#     'score': 0.9994128942489624,
#     'total_positive': 0,
#     'total_negative': 0.9994128942489624,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Studenicani': {'label': 'NEGATIVE',
#     'score': 0.9994128942489624,
#     'total_positive': 0,
#     'total_negative': 0.9994128942489624,
#     'count_positive': 0,
#     'count_negative': 1},
#    'more than 3 hours': {'label': 'NEGATIVE',
#     'score': 0.9962150454521179,
#     'total_positive': 0,
#     'total_negative': 0.9962150454521179,
#     'count_positive': 0,
#     'count_negative': 1},
#    '80,569': {'label': 'POSITIVE',
#     'score': 0.6244369149208069,
#     'total_positive': 0.6244369149208069,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '6.05 percent': {'label': 'POSITIVE',
#     'score': 0.6244369149208069,
#     'total_positive': 0.6244369149208069,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '11.05 percent': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '11.48': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Pehchevo': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '10.22 percent': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Novaci': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Demir Hisar': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '10.12': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Makedonski Brod': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '10.11 percent': {'label': 'POSITIVE',
#     'score': 0.9106865525245667,
#     'total_positive': 0.9106865525245667,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Lipkovo 0.97 percent': {'label': 'NEGATIVE',
#     'score': 0.9932324886322021,
#     'total_positive': 0,
#     'total_negative': 0.9932324886322021,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Dolneni 1.85 percent': {'label': 'NEGATIVE',
#     'score': 0.9932324886322021,
#     'total_positive': 0,
#     'total_negative': 0.9932324886322021,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Zelino': {'label': 'NEGATIVE',
#     'score': 0.9932324886322021,
#     'total_positive': 0,
#     'total_negative': 0.9932324886322021,
#     'count_positive': 0,
#     'count_negative': 1},
#    '1.82 percent': {'label': 'NEGATIVE',
#     'score': 0.9932324886322021,
#     'total_positive': 0,
#     'total_negative': 0.9932324886322021,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Plasnica 1.58 percent': {'label': 'NEGATIVE',
#     'score': 0.9932324886322021,
#     'total_positive': 0,
#     'total_negative': 0.9932324886322021,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://kanal5.com.mk/articles/373762/redjepi-izborite-fer-i-demokratski-zagrizhuva-niskiot-oddziv',
#   {'Rexhepi': {'label': 'NEGATIVE',
#     'score': 0.9801264703273773,
#     'total_positive': 0.9626896381378174,
#     'total_negative': 1.9602529406547546,
#     'count_positive': 1,
#     'count_negative': 2},
#    'Blerim River': {'label': 'POSITIVE',
#     'score': 0.9950171113014221,
#     'total_positive': 0.9950171113014221,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'today': {'label': 'POSITIVE',
#     'score': 0.9950171113014221,
#     'total_positive': 0.9950171113014221,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Redzepi': {'label': 'POSITIVE',
#     'score': 0.9927821159362793,
#     'total_positive': 0.9927821159362793,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'second': {'label': 'NEGATIVE',
#     'score': 0.9623298645019531,
#     'total_positive': 0,
#     'total_negative': 0.9623298645019531,
#     'count_positive': 0,
#     'count_negative': 1},
#    'two': {'label': 'POSITIVE',
#     'score': 0.9626896381378174,
#     'total_positive': 0.9626896381378174,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://fokus.mk/siljanovska-do-bojkotirachite-doma-mozhev-da-ostanam-i-jas-no-odluchiv-da-se-boram/',
#   {'Siljanovska': {'label': 'NEGATIVE',
#     'score': 0.9699897170066833,
#     'total_positive': 0,
#     'total_negative': 1.9399794340133667,
#     'count_positive': 0,
#     'count_negative': 2},
#    "VMRO-DPMNE's": {'label': 'NEGATIVE',
#     'score': 0.9796788692474365,
#     'total_positive': 0,
#     'total_negative': 0.9796788692474365,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gordana Siljanovska-Davkova': {'label': 'NEGATIVE',
#     'score': 0.9796788692474365,
#     'total_positive': 0,
#     'total_negative': 0.9796788692474365,
#     'count_positive': 0,
#     'count_negative': 1},
#    'first': {'label': 'NEGATIVE',
#     'score': 0.9796788692474365,
#     'total_positive': 0,
#     'total_negative': 0.9796788692474365,
#     'count_positive': 0,
#     'count_negative': 1},
#    'May 5th': {'label': 'POSITIVE',
#     'score': 0.9995748400688171,
#     'total_positive': 0.9995748400688171,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Macedonia': {'label': 'POSITIVE',
#     'score': 0.9995748400688171,
#     'total_positive': 0.9995748400688171,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://24.mk/details/koj-e-poglavar-na-islamskata-verska-zaednica',
#   {'Islamic': {'label': 'NEGATIVE',
#     'score': 0.9946680068969727,
#     'total_positive': 0,
#     'total_negative': 1.9893360137939453,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Skender Buzaku': {'label': 'NEGATIVE',
#     'score': 0.9872989058494568,
#     'total_positive': 0,
#     'total_negative': 1.9745978116989136,
#     'count_positive': 0,
#     'count_negative': 2},
#    'the Islamic Religious Community': {'label': 'NEGATIVE',
#     'score': 0.9946680068969727,
#     'total_positive': 0,
#     'total_negative': 0.9946680068969727,
#     'count_positive': 0,
#     'count_negative': 1},
#    'two': {'label': 'NEGATIVE',
#     'score': 0.9946680068969727,
#     'total_positive': 0,
#     'total_negative': 0.9946680068969727,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Reis Rexhepi': {'label': 'NEGATIVE',
#     'score': 0.9038127660751343,
#     'total_positive': 0,
#     'total_negative': 1.8076255321502686,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Albanian': {'label': 'NEGATIVE',
#     'score': 0.9459558427333832,
#     'total_positive': 0,
#     'total_negative': 1.8919116854667664,
#     'count_positive': 0,
#     'count_negative': 2},
#    'a few weeks ago': {'label': 'NEGATIVE',
#     'score': 0.9038127660751343,
#     'total_positive': 0,
#     'total_negative': 0.9038127660751343,
#     'count_positive': 0,
#     'count_negative': 1},
#    'IRC': {'label': 'NEGATIVE',
#     'score': 0.9659262100855509,
#     'total_positive': 0.9081978797912598,
#     'total_negative': 2.897778630256653,
#     'count_positive': 1,
#     'count_negative': 3},
#    '700': {'label': 'NEGATIVE',
#     'score': 0.9038127660751343,
#     'total_positive': 0,
#     'total_negative': 0.9038127660751343,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Macedonian mosques': {'label': 'NEGATIVE',
#     'score': 0.9038127660751343,
#     'total_positive': 0,
#     'total_negative': 0.9038127660751343,
#     'count_positive': 0,
#     'count_negative': 1},
#    'first': {'label': 'NEGATIVE',
#     'score': 0.9880989193916321,
#     'total_positive': 0,
#     'total_negative': 0.9880989193916321,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Friday': {'label': 'NEGATIVE',
#     'score': 0.9880989193916321,
#     'total_positive': 0,
#     'total_negative': 0.9880989193916321,
#     'count_positive': 0,
#     'count_negative': 1},
#    'mosques': {'label': 'NEGATIVE',
#     'score': 0.9880989193916321,
#     'total_positive': 0,
#     'total_negative': 0.9880989193916321,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Branko Gjorgjeski': {'label': 'NEGATIVE',
#     'score': 0.9880989193916321,
#     'total_positive': 0,
#     'total_negative': 0.9880989193916321,
#     'count_positive': 0,
#     'count_negative': 1},
#    'DUI': {'label': 'NEGATIVE',
#     'score': 0.9967832565307617,
#     'total_positive': 0,
#     'total_negative': 0.9967832565307617,
#     'count_positive': 0,
#     'count_negative': 1},
#    'DPA': {'label': 'NEGATIVE',
#     'score': 0.9967832565307617,
#     'total_positive': 0,
#     'total_negative': 0.9967832565307617,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Menduh Thaci': {'label': 'NEGATIVE',
#     'score': 0.9967832565307617,
#     'total_positive': 0,
#     'total_negative': 0.9967832565307617,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Rexhepi': {'label': 'NEGATIVE',
#     'score': 0.9967832565307617,
#     'total_positive': 0,
#     'total_negative': 0.9967832565307617,
#     'count_positive': 0,
#     'count_negative': 1},
#    'one': {'label': 'POSITIVE',
#     'score': 0.9081978797912598,
#     'total_positive': 0.9081978797912598,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'IVZ': {'label': 'NEGATIVE',
#     'score': 0.9993044137954712,
#     'total_positive': 0,
#     'total_negative': 0.9993044137954712,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Menduh Thaci - DPA': {'label': 'NEGATIVE',
#     'score': 0.9971826076507568,
#     'total_positive': 0,
#     'total_negative': 0.9971826076507568,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Suleiman Rexhepi': {'label': 'NEGATIVE',
#     'score': 0.9754918813705444,
#     'total_positive': 0,
#     'total_negative': 0.9754918813705444,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Riyasm': {'label': 'NEGATIVE',
#     'score': 0.9754918813705444,
#     'total_positive': 0,
#     'total_negative': 0.9754918813705444,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Reis': {'label': 'NEGATIVE',
#     'score': 0.9754918813705444,
#     'total_positive': 0,
#     'total_negative': 0.9754918813705444,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://kanal5.com.mk/articles/374466/mickoski-ochekuvam-da-ima-cenzus-na-5-maj',
#   {'May 5.VMRO': {'label': 'NEGATIVE',
#     'score': 0.9984527826309204,
#     'total_positive': 0,
#     'total_negative': 0.9984527826309204,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Christian Mickoski': {'label': 'NEGATIVE',
#     'score': 0.9984527826309204,
#     'total_positive': 0,
#     'total_negative': 0.9984527826309204,
#     'count_positive': 0,
#     'count_negative': 1},
#    'second': {'label': 'NEGATIVE',
#     'score': 0.9501291811466217,
#     'total_positive': 1.5634057521820068,
#     'total_negative': 1.9002583622932434,
#     'count_positive': 2,
#     'count_negative': 2},
#    'May 5': {'label': 'NEGATIVE',
#     'score': 0.9959233701229095,
#     'total_positive': 0.570446252822876,
#     'total_negative': 1.991846740245819,
#     'count_positive': 1,
#     'count_negative': 2},
#    'Gordana': {'label': 'POSITIVE',
#     'score': 0.9307329058647156,
#     'total_positive': 0.9307329058647156,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Siljanovska Davkova': {'label': 'POSITIVE',
#     'score': 0.9307329058647156,
#     'total_positive': 0.9307329058647156,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Mickoski': {'label': 'POSITIVE',
#     'score': 0.9972243010997772,
#     'total_positive': 1.9944486021995544,
#     'total_negative': 1.9375199675559998,
#     'count_positive': 2,
#     'count_negative': 2},
#    'the Easter Liturgy': {'label': 'NEGATIVE',
#     'score': 0.9933939576148987,
#     'total_positive': 0,
#     'total_negative': 0.9933939576148987,
#     'count_positive': 0,
#     'count_negative': 1},
#    '47': {'label': 'POSITIVE',
#     'score': 0.999177873134613,
#     'total_positive': 0.999177873134613,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Republic of Macedonia': {'label': 'NEGATIVE',
#     'score': 0.9756751656532288,
#     'total_positive': 0.999177873134613,
#     'total_negative': 1.9513503313064575,
#     'count_positive': 1,
#     'count_negative': 2},
#    '42.5 percent': {'label': 'POSITIVE',
#     'score': 0.999177873134613,
#     'total_positive': 0.999177873134613,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'first': {'label': 'POSITIVE',
#     'score': 0.999177873134613,
#     'total_positive': 0.999177873134613,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Siljanovska Davkovais': {'label': 'NEGATIVE',
#     'score': 0.9756751656532288,
#     'total_positive': 0,
#     'total_negative': 0.9756751656532288,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Central Committee': {'label': 'POSITIVE',
#     'score': 0.9982022047042847,
#     'total_positive': 0.9982022047042847,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'SPO': {'label': 'NEGATIVE',
#     'score': 0.9441260099411011,
#     'total_positive': 0,
#     'total_negative': 0.9441260099411011,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Statsus': {'label': 'NEGATIVE',
#     'score': 0.9441260099411011,
#     'total_positive': 0,
#     'total_negative': 0.9441260099411011,
#     'count_positive': 0,
#     'count_negative': 1},
#    'SDSM': {'label': 'POSITIVE',
#     'score': 0.9962463974952698,
#     'total_positive': 0.9962463974952698,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Ziadin Sela': {'label': 'NEGATIVE',
#     'score': 0.901805579662323,
#     'total_positive': 0,
#     'total_negative': 0.901805579662323,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Alliance for Albanians': {'label': 'NEGATIVE',
#     'score': 0.901805579662323,
#     'total_positive': 0,
#     'total_negative': 0.901805579662323,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Blerim River': {'label': 'NEGATIVE',
#     'score': 0.901805579662323,
#     'total_positive': 0,
#     'total_negative': 0.901805579662323,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://24.mk/details/cenzusot-i-rezultatot-neizvesni-vo-vtoriot-krug-od-pretsedatelskite-izbori',
#   {'second': {'label': 'NEGATIVE',
#     'score': 0.9970945517222086,
#     'total_positive': 0.9704562425613403,
#     'total_negative': 2.991283655166626,
#     'count_positive': 1,
#     'count_negative': 3},
#    'the presidential election?One week': {'label': 'POSITIVE',
#     'score': 0.9704562425613403,
#     'total_positive': 0.9704562425613403,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the election day': {'label': 'POSITIVE',
#     'score': 0.9704562425613403,
#     'total_positive': 0.9704562425613403,
#     'total_negative': 0.8839777708053589,
#     'count_positive': 1,
#     'count_negative': 1},
#    'two': {'label': 'POSITIVE',
#     'score': 0.9704562425613403,
#     'total_positive': 0.9704562425613403,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'SDSM': {'label': 'POSITIVE',
#     'score': 0.8585208058357239,
#     'total_positive': 1.7170416116714478,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'VMRO': {'label': 'POSITIVE',
#     'score': 0.9704562425613403,
#     'total_positive': 0.9704562425613403,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Albanian': {'label': 'POSITIVE',
#     'score': 0.9310395419597626,
#     'total_positive': 1.8620790839195251,
#     'total_negative': 0.9513982534408569,
#     'count_positive': 2,
#     'count_negative': 1},
#    'April 21': {'label': 'NEGATIVE',
#     'score': 0.9973387122154236,
#     'total_positive': 0,
#     'total_negative': 0.9973387122154236,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Blerim River': {'label': 'NEGATIVE',
#     'score': 0.9743684828281403,
#     'total_positive': 0.8056479096412659,
#     'total_negative': 1.9487369656562805,
#     'count_positive': 1,
#     'count_negative': 2},
#    'the Institute for Democracy': {'label': 'NEGATIVE',
#     'score': 0.9541868567466736,
#     'total_positive': 0,
#     'total_negative': 0.9541868567466736,
#     'count_positive': 0,
#     'count_negative': 1},
#    'DUI': {'label': 'NEGATIVE',
#     'score': 0.9527925550937653,
#     'total_positive': 0,
#     'total_negative': 1.9055851101875305,
#     'count_positive': 0,
#     'count_negative': 2},
#    '80,000': {'label': 'NEGATIVE',
#     'score': 0.9541868567466736,
#     'total_positive': 0,
#     'total_negative': 0.9541868567466736,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Alliance for Albanians': {'label': 'NEGATIVE',
#     'score': 0.9541868567466736,
#     'total_positive': 0,
#     'total_negative': 0.9541868567466736,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Besa': {'label': 'NEGATIVE',
#     'score': 0.9541868567466736,
#     'total_positive': 0,
#     'total_negative': 0.9541868567466736,
#     'count_positive': 0,
#     'count_negative': 1},
#    'VMRO-DPMNE': {'label': 'NEGATIVE',
#     'score': 0.9927753210067749,
#     'total_positive': 0,
#     'total_negative': 0.9927753210067749,
#     'count_positive': 0,
#     'count_negative': 1},
#    'anti-Albanian': {'label': 'NEGATIVE',
#     'score': 0.9927753210067749,
#     'total_positive': 0,
#     'total_negative': 0.9927753210067749,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Albanians': {'label': 'NEGATIVE',
#     'score': 0.9383765459060669,
#     'total_positive': 0,
#     'total_negative': 1.8767530918121338,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Siljanovska': {'label': 'NEGATIVE',
#     'score': 0.7736635506153107,
#     'total_positive': 0,
#     'total_negative': 1.5473271012306213,
#     'count_positive': 0,
#     'count_negative': 2},
#    'half': {'label': 'NEGATIVE',
#     'score': 0.9720867872238159,
#     'total_positive': 0,
#     'total_negative': 1.9441735744476318,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Stevo Pendarovski': {'label': 'NEGATIVE',
#     'score': 0.9927753210067749,
#     'total_positive': 0,
#     'total_negative': 0.9927753210067749,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gordana': {'label': 'NEGATIVE',
#     'score': 0.9927753210067749,
#     'total_positive': 0,
#     'total_negative': 0.9927753210067749,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Siljanovska Davkova': {'label': 'NEGATIVE',
#     'score': 0.9927753210067749,
#     'total_positive': 0,
#     'total_negative': 0.9927753210067749,
#     'count_positive': 0,
#     'count_negative': 1},
#    'first': {'label': 'NEGATIVE',
#     'score': 0.9513982534408569,
#     'total_positive': 0.8056479096412659,
#     'total_negative': 0.9513982534408569,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Marko Troshanovski - Institute for Democracy': {'label': 'POSITIVE',
#     'score': 0.7465853691101074,
#     'total_positive': 0.7465853691101074,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    "Bilal Kasami's": {'label': 'POSITIVE',
#     'score': 0.8056479096412659,
#     'total_positive': 0.8056479096412659,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Tuesday': {'label': 'POSITIVE',
#     'score': 0.8056479096412659,
#     'total_positive': 0.8056479096412659,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Pendarovski': {'label': 'NEGATIVE',
#     'score': 0.5545517802238464,
#     'total_positive': 0,
#     'total_negative': 0.5545517802238464,
#     'count_positive': 0,
#     'count_negative': 1},
#    '360 degrees': {'label': 'NEGATIVE',
#     'score': 0.8839777708053589,
#     'total_positive': 0,
#     'total_negative': 0.8839777708053589,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Sela': {'label': 'NEGATIVE',
#     'score': 0.8839777708053589,
#     'total_positive': 0,
#     'total_negative': 0.8839777708053589,
#     'count_positive': 0,
#     'count_negative': 1},
#    'a few days': {'label': 'NEGATIVE',
#     'score': 0.8839777708053589,
#     'total_positive': 0,
#     'total_negative': 0.8839777708053589,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Macedonian': {'label': 'POSITIVE',
#     'score': 0.8916228413581848,
#     'total_positive': 0.8916228413581848,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Alliance for Albanians': {'label': 'POSITIVE',
#     'score': 0.982490599155426,
#     'total_positive': 0.982490599155426,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://kanal5.com.mk/articles/374485/siljanovska-davkova-mislam-deka-ovoj-den-e-i-specifichna-opomena-za-site-nas',
#   {'Siljanovska Davkova': {'label': 'NEGATIVE',
#     'score': 0.9178485870361328,
#     'total_positive': 0,
#     'total_negative': 1.8356971740722656,
#     'count_positive': 0,
#     'count_negative': 2},
#    'this day': {'label': 'NEGATIVE',
#     'score': 0.9946892261505127,
#     'total_positive': 0,
#     'total_negative': 0.9946892261505127,
#     'count_positive': 0,
#     'count_negative': 1},
#    'today': {'label': 'NEGATIVE',
# ...
#     'count_positive': 1,
#     'count_negative': 0},
#    'Spasov': {'label': 'NEGATIVE',
#     'score': 0.580635666847229,
#     'total_positive': 0,
#     'total_negative': 0.580635666847229,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Zoran Zaev': {'label': 'POSITIVE',
#     'score': 0.9611865878105164,
#     'total_positive': 0.9611865878105164,
#     'total_negative': 0.580635666847229,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Pro Bono': {'label': 'NEGATIVE',
#     'score': 0.580635666847229,
#     'total_positive': 0,
#     'total_negative': 0.580635666847229,
#     'count_positive': 0,
#     'count_negative': 1},
#    'One': {'label': 'POSITIVE',
#     'score': 0.9986851811408997,
#     'total_positive': 0.9986851811408997,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Progress Institute - Tose Zafirov': {'label': 'POSITIVE',
#     'score': 0.9986851811408997,
#     'total_positive': 0.9986851811408997,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Katerina Janevska': {'label': 'POSITIVE',
#     'score': 0.9503596425056458,
#     'total_positive': 0.9503596425056458,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'first': {'label': 'POSITIVE',
#     'score': 0.9958895742893219,
#     'total_positive': 1.9917791485786438,
#     'total_negative': 0.9928471446037292,
#     'count_positive': 2,
#     'count_negative': 1},
#    'the National Security Council': {'label': 'POSITIVE',
#     'score': 0.9965994954109192,
#     'total_positive': 0.9965994954109192,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Ivanov': {'label': 'NEGATIVE',
#     'score': 0.9933865666389465,
#     'total_positive': 0.9707373976707458,
#     'total_negative': 0.9933865666389465,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Boris Josifovski': {'label': 'NEGATIVE',
#     'score': 0.9933865666389465,
#     'total_positive': 0,
#     'total_negative': 0.9933865666389465,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Next week': {'label': 'POSITIVE',
#     'score': 0.9707373976707458,
#     'total_positive': 0.9707373976707458,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the State Audit Office': {'label': 'POSITIVE',
#     'score': 0.9707373976707458,
#     'total_positive': 0.9707373976707458,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Administrative Inspectorate': {'label': 'POSITIVE',
#     'score': 0.9707373976707458,
#     'total_positive': 0.9707373976707458,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the day': {'label': 'POSITIVE',
#     'score': 0.9611865878105164,
#     'total_positive': 0.9611865878105164,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Euro -Mabbog Zbogar': {'label': 'POSITIVE',
#     'score': 0.9611865878105164,
#     'total_positive': 0.9611865878105164,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'a few days ago': {'label': 'POSITIVE',
#     'score': 0.9611865878105164,
#     'total_positive': 0.9611865878105164,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Hristijan Mickoski': {'label': 'POSITIVE',
#     'score': 0.9872786998748779,
#     'total_positive': 0.9872786998748779,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Elizabeta Gjorgjievska': {'label': 'POSITIVE',
#     'score': 0.9356183409690857,
#     'total_positive': 0.9356183409690857,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Congress of the World Psychiatric Organization': {'label': 'POSITIVE',
#     'score': 0.9356183409690857,
#     'total_positive': 0.9356183409690857,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://kanal5.com.mk/articles/376303/vo-apelacija-prodolzhi-sednicata-za-zhalbite-na-osudenite-za-divo-naselje',
#   {'Divo Naselje': {'label': 'NEGATIVE',
#     'score': 0.9946222305297852,
#     'total_positive': 0.7756967544555664,
#     'total_negative': 0.9946222305297852,
#     'count_positive': 1,
#     'count_negative': 1},
#    'The Skopje Court of Appeal': {'label': 'NEGATIVE',
#     'score': 0.9777851104736328,
#     'total_positive': 0,
#     'total_negative': 0.9777851104736328,
#     'count_positive': 0,
#     'count_negative': 1},
#    'today': {'label': 'NEGATIVE',
#     'score': 0.9777851104736328,
#     'total_positive': 0,
#     'total_negative': 0.9777851104736328,
#     'count_positive': 0,
#     'count_negative': 1},
#    '33': {'label': 'NEGATIVE',
#     'score': 0.9777851104736328,
#     'total_positive': 0,
#     'total_negative': 0.9777851104736328,
#     'count_positive': 0,
#     'count_negative': 1},
#    "Kumanovo's Divo Naselje.": {'label': 'NEGATIVE',
#     'score': 0.9777851104736328,
#     'total_positive': 0,
#     'total_negative': 0.9777851104736328,
#     'count_positive': 0,
#     'count_negative': 1},
#    'only two': {'label': 'NEGATIVE',
#     'score': 0.9646737575531006,
#     'total_positive': 0,
#     'total_negative': 0.9646737575531006,
#     'count_positive': 0,
#     'count_negative': 1},
#    '12 years': {'label': 'NEGATIVE',
#     'score': 0.9646737575531006,
#     'total_positive': 0,
#     'total_negative': 0.9646737575531006,
#     'count_positive': 0,
#     'count_negative': 1},
#    "Prosecutor's Office": {'label': 'NEGATIVE',
#     'score': 0.8589648604393005,
#     'total_positive': 0,
#     'total_negative': 0.8589648604393005,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Milanov': {'label': 'NEGATIVE',
#     'score': 0.9994519352912903,
#     'total_positive': 0,
#     'total_negative': 0.9994519352912903,
#     'count_positive': 0,
#     'count_negative': 1},
#    'first': {'label': 'NEGATIVE',
#     'score': 0.9892032742500305,
#     'total_positive': 0,
#     'total_negative': 0.9892032742500305,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://kanal5.com.mk/articles/376541/vmro-dpmne-filipche-e-celosno-nesposoben-za-vodenje-na-sektorot-na-zdravstvo',
#   {'Filipce': {'label': 'NEGATIVE',
#     'score': 0.9991583675146103,
#     'total_positive': 0,
#     'total_negative': 3.996633470058441,
#     'count_positive': 0,
#     'count_negative': 4},
#    'Venko Filipce': {'label': 'NEGATIVE',
#     'score': 0.9997376799583435,
#     'total_positive': 0,
#     'total_negative': 0.9997376799583435,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Gynecology and Obstetrics Clinic': {'label': 'NEGATIVE',
#     'score': 0.9986829161643982,
#     'total_positive': 0,
#     'total_negative': 0.9986829161643982,
#     'count_positive': 0,
#     'count_negative': 1},
#    '4': {'label': 'NEGATIVE',
#     'score': 0.9995998740196228,
#     'total_positive': 0,
#     'total_negative': 0.9995998740196228,
#     'count_positive': 0,
#     'count_negative': 1},
#    'VMRO-DPMNE Communications Center': {'label': 'NEGATIVE',
#     'score': 0.975105345249176,
#     'total_positive': 0,
#     'total_negative': 0.975105345249176,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://makfax.com.mk/sport/mizernata-sezona-za-real-zavrshi-mizerno-so-poraz-doma-od-betis-video/',
#   {'Betis': {'label': 'NEGATIVE',
#     'score': 0.9997015595436096,
#     'total_positive': 0,
#     'total_negative': 2.999104678630829,
#     'count_positive': 0,
#     'count_negative': 3},
#    'one': {'label': 'NEGATIVE',
#     'score': 0.9997656941413879,
#     'total_positive': 0,
#     'total_negative': 0.9997656941413879,
#     'count_positive': 0,
#     'count_negative': 1},
#    "Real Madrid's": {'label': 'NEGATIVE',
#     'score': 0.9997656941413879,
#     'total_positive': 0,
#     'total_negative': 0.9997656941413879,
#     'count_positive': 0,
#     'count_negative': 1},
#    '0': {'label': 'NEGATIVE',
#     'score': 0.999573290348053,
#     'total_positive': 0,
#     'total_negative': 0.999573290348053,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Los Blancos': {'label': 'NEGATIVE',
#     'score': 0.999573290348053,
#     'total_positive': 0,
#     'total_negative': 0.999573290348053,
#     'count_positive': 0,
#     'count_negative': 1},
#    '12': {'label': 'NEGATIVE',
#     'score': 0.999573290348053,
#     'total_positive': 0,
#     'total_negative': 0.999573290348053,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Spanish': {'label': 'NEGATIVE',
#     'score': 0.999573290348053,
#     'total_positive': 0,
#     'total_negative': 0.999573290348053,
#     'count_positive': 0,
#     'count_negative': 1},
#    'this season': {'label': 'NEGATIVE',
#     'score': 0.999573290348053,
#     'total_positive': 0,
#     'total_negative': 0.999573290348053,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Zinedine Zidane': {'label': 'NEGATIVE',
#     'score': 0.9979538917541504,
#     'total_positive': 0,
#     'total_negative': 0.9979538917541504,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Santiago Bernabeu': {'label': 'NEGATIVE',
#     'score': 0.9979538917541504,
#     'total_positive': 0,
#     'total_negative': 0.9979538917541504,
#     'count_positive': 0,
#     'count_negative': 1},
#    '38th': {'label': 'NEGATIVE',
#     'score': 0.9685179591178894,
#     'total_positive': 0,
#     'total_negative': 0.9685179591178894,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the second half': {'label': 'NEGATIVE',
#     'score': 0.9685179591178894,
#     'total_positive': 0,
#     'total_negative': 0.9685179591178894,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Lauren': {'label': 'NEGATIVE',
#     'score': 0.9685179591178894,
#     'total_positive': 0,
#     'total_negative': 0.9685179591178894,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Hesse Rodriguez': {'label': 'NEGATIVE',
#     'score': 0.9685179591178894,
#     'total_positive': 0,
#     'total_negative': 0.9685179591178894,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kaylor Navas': {'label': 'NEGATIVE',
#     'score': 0.9685179591178894,
#     'total_positive': 0,
#     'total_negative': 0.9685179591178894,
#     'count_positive': 0,
#     'count_negative': 1},
#    '75th': {'label': 'NEGATIVE',
#     'score': 0.9685179591178894,
#     'total_positive': 0,
#     'total_negative': 0.9685179591178894,
#     'count_positive': 0,
#     'count_negative': 1},
#    'goal.to': {'label': 'NEGATIVE',
#     'score': 0.9685179591178894,
#     'total_positive': 0,
#     'total_negative': 0.9685179591178894,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Madrid': {'label': 'NEGATIVE',
#     'score': 0.9685179591178894,
#     'total_positive': 0,
#     'total_negative': 0.9685179591178894,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the season': {'label': 'POSITIVE',
#     'score': 0.8827471137046814,
#     'total_positive': 0.8827471137046814,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '68': {'label': 'POSITIVE',
#     'score': 0.8827471137046814,
#     'total_positive': 0.8827471137046814,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Barcelona': {'label': 'POSITIVE',
#     'score': 0.8827471137046814,
#     'total_positive': 0.8827471137046814,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '86': {'label': 'POSITIVE',
#     'score': 0.8827471137046814,
#     'total_positive': 0.8827471137046814,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '89': {'label': 'POSITIVE',
#     'score': 0.8827471137046814,
#     'total_positive': 0.8827471137046814,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'only 10': {'label': 'POSITIVE',
#     'score': 0.8827471137046814,
#     'total_positive': 0.8827471137046814,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '50': {'label': 'POSITIVE',
#     'score': 0.9991471767425537,
#     'total_positive': 0.9991471767425537,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://kanal5.com.mk/articles/376323/sredba-osmani-koja',
#   {'Osmani': {'label': 'POSITIVE',
#     'score': 0.9982675313949585,
#     'total_positive': 2.9948025941848755,
#     'total_negative': 0,
#     'count_positive': 3,
#     'count_negative': 0},
#    'European': {'label': 'NEGATIVE',
#     'score': 0.5326974987983704,
#     'total_positive': 0,
#     'total_negative': 0.5326974987983704,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Bujar Osmani': {'label': 'NEGATIVE',
#     'score': 0.5326974987983704,
#     'total_positive': 0,
#     'total_negative': 0.5326974987983704,
#     'count_positive': 0,
#     'count_negative': 1},
#    'OSCE': {'label': 'POSITIVE',
#     'score': 0.9979702830314636,
#     'total_positive': 1.9959405660629272,
#     'total_negative': 0.5326974987983704,
#     'count_positive': 2,
#     'count_negative': 1},
#    'Clemens': {'label': 'NEGATIVE',
#     'score': 0.5326974987983704,
#     'total_positive': 0,
#     'total_negative': 0.5326974987983704,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://makfax.com.mk/svet/%d0%b4%d0%b8%d0%bc%d0%b8%d1%82%d1%80%d0%be%d0%b2-%d0%b8-%d0%bf%d1%80%d0%b8%d0%bd%d1%86%d0%be%d1%82-%d0%b5%d0%b4%d0%b2%d0%b0%d1%80%d0%b4-%d0%bf%d1%80%d0%b8%d1%81%d1%83%d1%81%d1%82%d0%b2%d1%83%d0%b2/',
#   {'Prince Edward': {'label': 'POSITIVE',
#     'score': 0.9947108030319214,
#     'total_positive': 1.9894216060638428,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'the National Philharmonic': {'label': 'POSITIVE',
#     'score': 0.9947108030319214,
#     'total_positive': 1.9894216060638428,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'Dimitrov': {'label': 'POSITIVE',
#     'score': 0.9890256226062775,
#     'total_positive': 1.978051245212555,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'Nikola Dimitrov': {'label': 'POSITIVE',
#     'score': 0.9886279702186584,
#     'total_positive': 1.977255940437317,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'Majesty Prince Edward': {'label': 'POSITIVE',
#     'score': 0.9886279702186584,
#     'total_positive': 1.977255940437317,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'Vesex': {'label': 'POSITIVE',
#     'score': 0.9886279702186584,
#     'total_positive': 1.977255940437317,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'the National Philharmonic in Skopje': {'label': 'POSITIVE',
#     'score': 0.9939154982566833,
#     'total_positive': 0.9939154982566833,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Northern Macedonia': {'label': 'POSITIVE',
#     'score': 0.9939154982566833,
#     'total_positive': 0.9939154982566833,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'two': {'label': 'POSITIVE',
#     'score': 0.9998623132705688,
#     'total_positive': 0.9998623132705688,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '10 to 15 years': {'label': 'POSITIVE',
#     'score': 0.9968113303184509,
#     'total_positive': 0.9968113303184509,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the United Kingdom Galloway': {'label': 'POSITIVE',
#     'score': 0.9833404421806335,
#     'total_positive': 0.9833404421806335,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Ministers Damjan Manchevski': {'label': 'POSITIVE',
#     'score': 0.9833404421806335,
#     'total_positive': 0.9833404421806335,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Mila Jarovska': {'label': 'POSITIVE',
#     'score': 0.9833404421806335,
#     'total_positive': 0.9833404421806335,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the diplomatic corps': {'label': 'POSITIVE',
#     'score': 0.9833404421806335,
#     'total_positive': 0.9833404421806335,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    "Prince Edward's": {'label': 'POSITIVE',
#     'score': 0.9833404421806335,
#     'total_positive': 0.9833404421806335,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}]]

# %%
# THE FINAL RESULT UNTIL NOW IS url_sentiments: List of [url, entity_sentiments: map of key entity and value sentiment]

# %%
def get_hostname(url):
    return urlparse(url).hostname

# This function is used to merge the list of entity_sentiment of two urls that have the same hostname
# entity_sentiments1, entity_sentiments2 are maps with key entity and value sentiment
def merge_sentiments(entity_sentiments1, entity_sentiments2):
    for entity, sentiment_values in entity_sentiments2.items():
        if entity not in entity_sentiments1:
            entity_sentiments1[entity] = sentiment_values
        else:
            for key, value in sentiment_values.items():
                if key.startswith('total_') or key.startswith('count_'):
                    entity_sentiments1[entity][key] += value
               
    return entity_sentiments1

# %%
# import copy
# test = url_sentiments[0]
# test_list = [copy.deepcopy(test) for _ in range(4)]

# %%
# test_list

# %%
# Transform from url_sentiments list to hostname_sentiments list
# Merge the sentiment values for the same entity
# Append the sentiment values for new entities
hostname_sentiments = {}

for url, sentiments in url_sentiments:
    hostname = get_hostname(url)
    if hostname not in hostname_sentiments:
        hostname_sentiments[hostname] = sentiments
    else:
        hostname_sentiments[hostname] = merge_sentiments(hostname_sentiments[hostname], sentiments)

# Convert the dictionary back to a list
hostname_sentiments_list = [[hostname, sentiments] for hostname, sentiments in hostname_sentiments.items()]

print(hostname_sentiments_list)
# Out:
# [['24.mk', {'Zaev': {'label': 'NEGATIVE', 'score': 0.9454014450311661, 'total_positive': 2.9939094185829163, 'total_negative': 3.7816057801246643, 'count_positive': 3, 'count_negative': 4}, 'SDSM': {'label': 'POSITIVE', 'score': 0.9980232417583466, 'total_positive': 3.713088095188141, 'total_negative': 2.6523898243904114, 'count_positive': 4, 'count_negative': 3}, 'Zoran Zaev': {'label': 'NEGATIVE', 'score': 0.918300211429596, 'total_positive': 0, 'total_negative': 0.918300211429596, 'count_positive': 0, 'count_negative': 1}, 'The Republic of Northern Macedonia': {'label': 'POSITIVE', 'score': 0.9984772801399231, 'total_positive': 0.9984772801399231, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0}, 'Europe': {'label': 'POSITIVE', 'score': 0.9989223480224609, 'total_positive': 0.9989223480224609, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0}, 'Stevo Pendarovski': {'label': 'POSITIVE', 'score': 0.9980781972408295, 'total_positive': 2.994282603263855, 'total_negative': 2.7255967259407043, 'count_positive': 3, 'count_negative': 3}, 'NATO': {'label': 'POSITIVE', 'score': 0.9980853497982025, 'total_positive': 1.996170699596405, 'total_negative': 0, 'count_positive': 2, 'count_negative': 0}, 'the end of the year': {'label': 'POSITIVE', 'score': 0.9995054006576538, 'total_positive': 0.9995054006576538, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0}, 'EU': {'label': 'POSITIVE', 'score': 0.9974488615989685, 'total_positive': 1.994897723197937, 'total_negative': 0, 'count_positive': 2, 'count_negative': 0}, 'this summer': {'label': 'POSITIVE', 'score': 0.9982324242591858, 'total_positive': 0.9982324242591858, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0}, 'two years': {'label': 'NEGATIVE', 'score': 0.9314896464347839, 'total_positive': 0, 'total_negative': 0.9314896464347839, 'count_positive': 0, 'count_negative': 1}, '500': {'label': 'NEGATIVE', 'score': 0.9956507086753845, 'total_positive': 0, 'total_negative': 0.9956507086753845, 'count_positive': 0, 'count_negative': 1}, '2020.In': {'label': 'NEGATIVE', 'score': 0.9956507086753845, 'total_positive': 0, 'total_negative': 0.9956507086753845, 'count_positive': 0, 'count_negative': 1}, 'Macedonians': {'label': 'NEGATIVE', 'score': 0.9956507086753845, 'total_positive': 0, 'total_negative': 0.9956507086753845, 'count_positive': 0, 'count_negative': 1}, 'Macedonian': {'label': 'NEGATIVE', 'score': 0.9956507086753845, 'total_positive': 0.8916228413581848, 'total_negative': 0.9956507086753845, 'count_positive': 1, 'count_negative': 1}, 'two': {'label': 'POSITIVE', 'score': 0.991877555847168, 'total_positive': 1.9623337984085083, 'total_negative': 2.9902048110961914, 'count_positive': 2, 'count_negative': 3}, 'one': {'label': 'POSITIVE', 'score': 0.991877555847168, 'total_positive': 1.9000754356384277, 'total_negative': 0, 'count_positive': 2, 'count_negative': 0}, 'Pendarovski': {'label': 'POSITIVE', 'score': 0.991877555847168, 'total_positive': 1.9769132137298584, 'total_negative': 1.2892213463783264, 'count_positive': 2, 'count_negative': 2}, '31 party': {'label': 'POSITIVE', 'score': 0.991877555847168, 'total_positive': 0.991877555847168, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0}, 'Siljanovska': {'label': 'NEGATIVE', 'score': 0.8829853236675262, 'total_positive': 0, 'total_negative': 3.313297748565674, 'count_positive': 0, 'count_negative': 4}, 'only one': {'label': 'NEGATIVE', 'score': 0.8018938302993774, 'total_positive': 0, 'total_negative': 0.8018938302993774, 'count_positive': 0, 'count_negative': 1}, 'Gruevski".-Stevo': {'label': 'NEGATIVE', 'score': 0.8018938302993774, 'total_positive': 0, 'total_negative': 0.8018938302993774, 'count_positive': 0, 'count_negative': 1}, 'Gordana Siljanovska': {'label': 'NEGATIVE', 'score': 0.9981518387794495, 'total_positive': 0, 'total_negative': 0.9981518387794495, 'count_positive': 0, 'count_negative': 1}, 'Gjorge Ivanov': {'label': 'NEGATIVE', 'score': 0.9988002 ...

# %%
print("Max index that can be set as hostname_index is " + str(len(hostname_sentiments_list) - 1))
# Out:
# Max index that can be set as hostname_index is 4

# %%
i=0
for hostname, sentiment in hostname_sentiments_list:
    print(str(i) + ": " + hostname)
    i+=1
# Out:
# 0: 24.mk
# 1: kanal5.com.mk
# 2: fokus.mk
# 3: makfax.com.mk
# 4: netpress.com.mk

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

data = hostname_sentiments_list

hostname_index = 4

# %%
# Extract entities and their respective counts (here I'm using the positive counts)
word_frequencies = {entity: details['count_positive'] for entity, details in data[hostname_index][1].items()}

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_frequencies)


plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Entities with positive sentiment from " + data[hostname_index][0], fontsize=18, pad=20)  # Adding a title here
plt.show()

# %%
# Extract entities and their respective counts (here I'm using the negative counts)
word_frequencies = {entity: details['count_negative'] for entity, details in data[hostname_index][1].items()}

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_frequencies)


plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Entities with negative sentiment from " + data[hostname_index][0], fontsize=18, pad=20)  # Adding a title here
plt.show()

# %%
# # Find entities that show up the most, both in all news portals and in specific news portals
# for hostname, sentiment in hostname_sentiments_list:
    
print("News portals and how many times they mention an entity:\n")
    
for hostname, entity_sentiment_map in hostname_sentiments_list:
    # Create a list of tuples (entity_name, total_mentions)
    mentions = [(entity, details['count_positive'] + details['count_negative']) for entity, details in entity_sentiment_map.items()]
    
    # Sort the entities by total mentions in descending order
    sorted_mentions = sorted(mentions, key=lambda x: x[1], reverse=True)
    
    # Get the top 10 entities
    top_10_entities = sorted_mentions[:10]
    
    print(hostname)
    for entity, count in top_10_entities:
        print(f"  {entity}: {count} mentions")
    print("\n")
# Out:
# News portals and how many times they mention an entity:
#
# 24.mk
#   Zaev: 7 mentions
#   SDSM: 7 mentions
#   Stevo Pendarovski: 6 mentions
#   second: 6 mentions
#   two: 5 mentions
#   first: 5 mentions
#   Albanian: 5 mentions
#   Pendarovski: 4 mentions
#   Siljanovska: 4 mentions
#   Macedonia: 4 mentions
#
#
# kanal5.com.mk
#   today: 8 mentions
#   second: 7 mentions
#   Siljanovska Davkova: 6 mentions
#   the Republic of Macedonia: 6 mentions
#   first: 6 mentions
#   Siljanovska: 4 mentions
#   Stevo Pendarovski: 4 mentions
#   Blerim River: 4 mentions
#   Mickoski: 4 mentions
#   Vardar: 4 mentions
#
#
# fokus.mk
#   Siljanovska: 5 mentions
#   Tamara: 5 mentions
#   Albanians: 4 mentions
#   Bogovinje: 4 mentions
#   Albanian: 3 mentions
#   Zelino: 3 mentions
#   Prilep: 3 mentions
#   Sveti Nikole: 3 mentions
#   all night: 3 mentions
#   VMRO-DPMNE: 3 mentions
#
#
# makfax.com.mk
#   Betis: 3 mentions
#   Ajax 99.9%: 2 mentions
#   Netherlands: 2 mentions
#   Utrecht: 2 mentions
#   two: 2 mentions
#   75th: 2 mentions
#   Ajax: 2 mentions
#   Prince Edward: 2 mentions
#   the National Philharmonic: 2 mentions
#   Dimitrov: 2 mentions
#
#
# netpress.com.mk
#   Pendarovski: 6 mentions
#   first: 3 mentions
#   Zoran Zaev: 2 mentions
#   Ivanov: 2 mentions
#   week: 1 mentions
#   Vodno: 1 mentions
#   Stevo Pendarovski: 1 mentions
#   the Presidential Service: 1 mentions
#   Mile Bosniakovski: 1 mentions
#   Sitel: 1 mentions

# %%
# WRITE NEWS TO FILE
################################################################################################################################
# file_path = "final.txt"
# delimiter = "____###DELIMITER###____"  # Choose a delimiter that won't appear in your data

# with open(file_path, "w", encoding="utf-8") as file:
#     # Iterate through the map and write each key-value pair
#     for key, value in translated_texts.items():
#         file.write(f"{key}{delimiter}{value}\n")  # Add a newline character after each pair

# print("Key-value pairs written to the file successfully.")

# %%
# READ NEWS FROM FILE
################################################################################################################################
# file_path = "final.txt"
# delimiter = "____###DELIMITER###____"  # The same delimiter you used while saving

# read_map = {}

# with open(file_path, "r", encoding="utf-8") as file:
#     for line in file:
#         key, value = line.strip().split(delimiter, 1)
#         read_map[key] = value

# print("Key-value pairs read from the file:", read_map)

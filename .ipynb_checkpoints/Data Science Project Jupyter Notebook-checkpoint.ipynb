# %%
import numpy as np
import pandas as pd
from urllib.parse import urlparse

import requests
from bs4 import BeautifulSoup
from IPython.display import HTML
# Setting up 'requests' to make HTTPS requests properly takes some extra steps... we'll skip them for now.
requests.packages.urllib3.disable_warnings()
# Import all modules that are required
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

import time

# %%
def generate_week_strings(start_year, start_week, end_year, end_week):
    week_strings = []

    for year in range(start_year, end_year + 1):
        start = start_week if year == start_year else 1
        end = end_week if year == end_year else 53

        for week in range(start, end + 1):
          #TODO CHANGE LATER range(1, 11)
          for num in range(1, 2):
            #TODO CHANGE LATER range(1, 11)
            week_string = f"week/{year}/{week}/{num}"
            week_strings.append(week_string)

    return week_strings

start_year = 2020
start_week = 15
end_year = 2020
end_week = 20

week_strings = generate_week_strings(start_year, start_week, end_year, end_week)

# %%
len(week_strings)
# Out:
# 6

# %%
week_strings
# Out:
# ['week/2020/15/1',
#  'week/2020/16/1',
#  'week/2020/17/1',
#  'week/2020/18/1',
#  'week/2020/19/1',
#  'week/2020/20/1']

# %%
list_of_articles = []
list_of_time_mk_urls = []
for week_string in week_strings:
  week_url = "https://time.mk/" + week_string
  response = requests.get(week_url)
  response.encoding = 'utf-8'
  soup = BeautifulSoup(response.text, "html.parser")
  list_of_articles.extend(soup.find_all(class_="cluster"))
for article in list_of_articles:
  first_anchor_tag = article.select_one('a')
  list_of_time_mk_urls.append("https://time.mk/" + first_anchor_tag.get("href"))

# %%
print(list_of_time_mk_urls)
# Out:
# ['https://time.mk/r/9068e4b15a/9a07ecc2a0/', 'https://time.mk/r/ae7e77a0e5/25430fb44d/', 'https://time.mk/r/6ba55c8a71/20e15116d9/', 'https://time.mk/r/e94292937d/dae34e86ce/', 'https://time.mk/r/26e21000c2/19a5655470/', 'https://time.mk/r/5e384a9dfc/5bf1a0b9e3/', 'https://time.mk/r/e9a0783157/f35729cc71/', 'https://time.mk/r/5942e809ad/3fe888e5e1/', 'https://time.mk/r/53d6c9f5c1/0b2ce4efa2/', 'https://time.mk/r/5f682b46fb/c0726bade6/', 'https://time.mk/r/c6e385f261/a1eedde4d4/', 'https://time.mk/r/317ba786c8/1f54c70377/', 'https://time.mk/r/215ef78ae6/5f7a131255/', 'https://time.mk/r/971b3ff52f/decb96cdfe/', 'https://time.mk/r/c88d61e521/26c91bdd17/', 'https://time.mk/r/a7b34181d6/9f6275f767/', 'https://time.mk/r/83b937d2c9/3adb84fb5f/', 'https://time.mk/r/fd43531e81/fffb8d45f1/', 'https://time.mk/r/cc6737d5e1/1a8ceaae32/', 'https://time.mk/r/7a6b648473/164e60b43f/', 'https://time.mk/r/aa54c4f4d2/84cda2a7b0/', 'https://time.mk/r/044c7a7a24/9630624038/', 'https://time.mk/r/b094762563/d93ffd9d7c/', 'https://time.mk/r/c92b8d0b30/71709f53d7/', 'https://time.mk/r/572f7c2f27/cc9c81a3f4/', 'https://time.mk/r/44e87e7ffa/5b08d05bfb/', 'https://time.mk/r/cadfdf221c/ae384374ff/', 'https://time.mk/r/ba7e4b2c1d/4ae9fd1548/', 'https://time.mk/r/5a22230f17/7fa55184fc/', 'https://time.mk/r/fd3763a742/d99801b742/', 'https://time.mk/r/e347e1c8fd/7ac906710e/', 'https://time.mk/r/e60be43d59/ef7977dc70/', 'https://time.mk/r/bd6b49b161/6aa0a28b2f/', 'https://time.mk/r/984cfcf9ab/6dc9493526/', 'https://time.mk/r/12e2fbcd33/79c031ffc9/', 'https://time.mk/r/2ca60513ee/647d84b2e4/', 'https://time.mk/r/8f569297fb/87fd5acd0f/', 'https://time.mk/r/b6a2abab3c/651b368a5c/', 'https://time.mk/r/3790531c29/9ad89fafa0/', 'https://time.mk/r/95eabc6fd4/65d1cafb5c/', 'https://time.mk/r/374aeb6544/34efe1b1bd/', 'https://time.mk/r/c099621bf2/0dc618183b/', 'https://time.mk/r/5b7ec32ebc/1c0f09416a/', 'https://time.mk/r/aba2d4b849/93d6fc1c12/', 'https://time.mk/r/28164e2ece/95f6bef106/', 'https://time.mk/r/5a819031e9/7d983af67d/', 'https://time.mk/r/4d3cb8740d/7f8112c0d9/', 'https://time.mk/r/e6706e7717/26d5838064/', 'https://time.mk/r/a48484a723/1097773eef/', 'https://time.mk/r/1d980ae70d/c302a4ac81/', 'https://time.mk/r/eb2fc2eb10/3ae734640b/', 'https://time.mk/r/81f3a4f36b/7ed0d9160a/', 'https://time.mk/r/f31c746b9b/a840a3d338/', 'https://time.mk/r/5d25eaf118/e5464e24de/', 'https://time.mk/r/11e8edadea/17f5a01268/', 'https://time.mk/r/c290df7260/e0df1a0af0/', 'https://time.mk/r/19b0734f3b/730873720a/', 'https://time.mk/r/6541019dc5/f6dcd6e4da/', 'https://time.mk/r/4c7cc1651d/edc629db8c/', 'https://time.mk/r/e3a009bf43/0f905736f5/']

# %%
len(list_of_time_mk_urls)
# Out:
# 60

# %%
def parseVecerNews(url, content):
    
  soup = BeautifulSoup(content, 'html.parser')

  title = soup.find(class_='entry-title').text.strip() if soup.find(class_='entry-title') else None
  # subtitle = soup.find(class_='td-post-sub-title').text.strip() if soup.find(class_='td-post-sub-title') else None
  subtitle = soup.find(class_='entry-title').text.strip() if soup.find(class_='entry-title') else None
  date = soup.find(class_='entry-date updated td-module-date').text.strip() if soup.find(class_='entry-date updated td-module-date') else None
  main_content = soup.find(class_='td-post-content').text.strip() if soup.find(class_='td-post-content') else None

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseNovaMakedonijaNews(url, content):
  
  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  subtitle = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  date = soup.find(class_='entry-date updated td-module-date').text.strip() if soup.find(class_='entry-date updated td-module-date') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseTv21News(url, content):

  soup = BeautifulSoup(content, 'html.parser')
  title = soup.find(class_='tdb-title-text').text.strip() if soup.find(class_='tdb-title-text') else None
  subtitle = soup.find(class_='tdb-title-text').text.strip() if soup.find(class_='tdb-title-text') else None
  date = soup.find(class_='entry-date updated td-module-date').text.strip() if soup.find(class_='entry-date updated td-module-date') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = '\n'.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parse360stepeni(url, content):

  soup = BeautifulSoup(content, 'html.parser')
  title = soup.find(class_='txt--white txt--center').text.strip() if soup.find(class_='txt--white txt--center') else None
  subtitle = soup.find(class_='txt--white txt--center').text.strip() if soup.find(class_='txt--white txt--center') else None
  date = soup.find(class_='single__post-meta single__post_author txt--center').text.strip() if soup.find(class_='single__post-meta single__post_author txt--center') else None
  main_content = soup.find(class_='entry-content').text.strip() if soup.find(class_='entry-content') else None
  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseAlfaNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')

  title = soup.find(class_='entry-title').text.strip() if soup.find(class_='entry-title') else None
  subtitle = soup.find(class_='entry-title').text.strip() if soup.find(class_='entry-title') else None
  date = soup.find(class_='item-metadata posts-date').text.strip() if soup.find(class_='item-metadata posts-date') else None
  main_content = soup.find(class_='entry-content').text.strip() if soup.find(class_='entry-content') else None

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSitelNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find('div', class_='panel-pane pane-node-title').find("h1").text.strip() if soup.find('div', class_='panel-pane pane-node-title').find("h1") else None
  subtitle = soup.find('div', class_='panel-pane pane-node-title').find("h1").text.strip() if soup.find('div', class_='panel-pane pane-node-title').find("h1") else None
  date = soup.find(class_='data-na-objava').text.strip() if soup.find(class_='data-na-objava') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSdkNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find(class_='post-title entry-title').text.strip() if soup.find(class_='post-title entry-title') else None
  subtitle = soup.find(class_='post-title entry-title').text.strip() if soup.find(class_='post-title entry-title') else None
  date = soup.find("span", class_='value').text.strip() if soup.find("span", class_='value') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseFokusNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find(class_='post-title single-post-title entry-title').text.strip() if soup.find(class_='post-title single-post-title entry-title') else None
  subtitle = soup.find(class_='post-title single-post-title entry-title').text.strip() if soup.find(class_='post-title single-post-title entry-title') else None
  date = soup.find(class_='entry-date published').text.strip() if soup.find(class_='entry-date published') else None

  news_paragraphs = soup.find(class_="inner-post-entry entry-content").find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSport1News(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find(class_='title').text.strip() if soup.find(class_='title') else None
  subtitle = soup.find(class_='teaser field').text.strip() if soup.find(class_='teaser field') else None
  date = soup.find(class_='submitted').text.strip() if soup.find(class_='submitted') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseKanal5News(url, content):

  #Need to decode first from bytes to text
  html_content = content.decode("utf-8")
  soup = BeautifulSoup(html_content, 'html.parser')


  title = soup.find("h1", class_='article-title').text.strip() if soup.find("h1", class_='article-title') else None
  subtitle = soup.find(class_='subtitle').text.strip() if soup.find(class_='subtitle') else None
  date = soup.find(class_='article-published').text.strip() if soup.find(class_='article-published') else None
  main_content = soup.find(class_ = 'article-text').text.strip() if soup.find(class_ = 'article-text') else None

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseRepublikaNews(url, content):

  #Need to decode first from bytes to text
  html_content = content.decode("utf-8")
  soup = BeautifulSoup(html_content, 'html.parser')


  title = soup.find("h1", class_='title mb-3').text.strip() if soup.find("h1", class_='title mb-3') else None
  subtitle = soup.find("h1", class_='title mb-3').text.strip() if soup.find("h1", class_='title mb-3') else None
  date = soup.find("span", class_='date').text.strip() if soup.find("span", class_='date') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parsePuls24News(url, content):

  #Need to decode first from bytes to text
  html_content = content.decode("utf-8")
  soup = BeautifulSoup(html_content, 'html.parser')


  title = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  subtitle = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  date = soup.find(class_='entry-date updated published').text.strip() if soup.find(class_='entry-date updated published') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseMkdNews(url, content):

  #Need to decode first from bytes to text
  html_content = content.decode("utf-8")
  soup = BeautifulSoup(html_content, 'html.parser')


  title = soup.find("h1", class_='main-article-title').text.strip() if soup.find("h1", class_='main-article-title') else None
  subtitle = soup.find("div", id='podnaslov').text.strip() if soup.find("div", id='podnaslov') else None
  date = soup.find(class_='row mx-0 article-info mb-3').find("div").find("div").text.strip() if soup.find(class_='row mx-0 article-info mb-3').find("div").find("div") else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      "url" : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseAlsatNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='post-title entry-title').text.strip() if soup.find("h1", class_='post-title entry-title') else None
  subtitle = soup.find(class_='entry-sub-title').text.strip() if soup.find(class_='entry-sub-title') else None
  date = soup.find(class_='date meta-item tie-icon').text.strip() if soup.find(class_='date meta-item tie-icon') else None

  news_paragraphs = soup.find_all('p')
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSlobodnaEvropaNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='title pg-title').text.strip() if soup.find("h1", class_='title pg-title') else None
  subtitle = soup.find("h1", class_='title pg-title').text.strip() if soup.find("h1", class_='title pg-title') else None
  date = soup.find("time").text.strip() if soup.find("time") else None
  main_content = soup.find(class_="wsw").text.strip() if soup.find(class_="wsw") else None

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseMakfaksNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='mvp-post-title left entry-title').text.strip() if soup.find("h1", class_='mvp-post-title left entry-title') else None
  subtitle = soup.find("h1", class_='mvp-post-title left entry-title').text.strip() if soup.find("h1", class_='mvp-post-title left entry-title') else None
  date = soup.find(class_="post-date updated").text.strip() if soup.find(class_="post-date updated") else None

  news_paragraphs = soup.find(id="mvp-content-main").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseMkVoaNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='title pg-title').text.strip() if soup.find("h1", class_='title pg-title') else None
  subtitle = soup.find("h1", class_='title pg-title').text.strip() if soup.find("h1", class_='title pg-title') else None
  date = soup.find("time").text.strip() if soup.find("time") else None

  news_paragraphs = soup.find(class_="wsw").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseNetpressNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  subtitle = soup.find("h1", class_='entry-title').text.strip() if soup.find("h1", class_='entry-title') else None
  date = soup.find(class_="entry-date updated td-module-date").text.strip() if soup.find(class_="entry-date updated td-module-date") else None

  news_paragraphs = soup.find(class_="td-post-content").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseSlobodenPecatNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='post-main-title').text.strip() if soup.find("h1", class_='post-main-title') else None
  subtitle = soup.find("h1", class_='post-main-title').text.strip() if soup.find("h1", class_='post-main-title') else None
  date = soup.find("time")["datetime"].strip() if soup.find("time") else None

  news_paragraphs = soup.find(class_="post-body-inner").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseMakpressNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')

  title = soup.find("div", class_='page-header').find("h1").text.strip() if soup.find("div", class_='page-header') else None
  subtitle = soup.find("div", class_='page-header').find("h1").text.strip() if soup.find("div", class_='page-header').find("h1") else None
  date = soup.find("div", class_="time").text.strip() if soup.find("div", class_="time") else None

  news_paragraphs = soup.find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseDWNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')

  title = soup.select_one(".content-area").find("header").find("h1").text.strip() if soup.select_one(".content-area").find("header").find("h1") else None
  subtitle = soup.select_one(".content-area").find("header").find("h1").text.strip() if soup.select_one(".content-area").find("header").find("h1") else None
  date = soup.find("time").text.strip() if soup.find("time") else None

  news_paragraphs = soup.select_one(".rich-text.has-italic").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parse24MkNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')

  title = soup.find(class_="post-title-area").find("h2", class_='post-title').text.strip() if soup.find(class_="post-title-area").find("h2", class_='post-title') else None
  subtitle = soup.find(class_="post-title-area").find("h2", class_='post-title').text.strip() if soup.find(class_="post-title-area").find("h2", class_='post-title') else None
  date = soup.find("span", class_="post-date").text.strip() if soup.find("span", class_="post-date") else None

  news_paragraphs = soup.find(class_="entry-content").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseRadioMofNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='post-title').text.strip() if soup.find("h1", class_='post-title') else None
  subtitle = soup.find("h1", class_='post-title').text.strip() if soup.find("h1", class_='post-title') else None
  date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

  news_paragraphs = soup.find(class_="post-content description").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseCentarMkNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='entry-title penci-entry-title penci-title-center').text.strip() if soup.find("h1", class_='entry-title penci-entry-title penci-title-center') else None
  subtitle = soup.find("h1", class_='entry-title penci-entry-title penci-title-center').text.strip() if soup.find("h1", class_='entry-title penci-entry-title penci-title-center') else None
  date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

  news_paragraphs = soup.find(class_="penci-entry-content entry-content").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseA1OnNews(url, content):

  soup = BeautifulSoup(content, 'html.parser')


  title = soup.find("h1", class_='entry-title penci-entry-title').text.strip() if soup.find("h1", class_='entry-title penci-entry-title') else None
  subtitle = soup.find("h1", class_='entry-title penci-entry-title').text.strip() if soup.find("h1", class_='entry-title penci-entry-title') else None
  date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

  news_paragraphs = soup.find(class_="penci-entry-content entry-content").find_all("p")
  # Accumulate the text from all news paragraphs
  main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs[:-1])

  news_data = {
      'url' : url,
      'title': title,
      'subtitle': subtitle,
      'date': date,
      'main_content': main_content
  }

  return news_data

def parseTelmaNews(url, content):

    soup = BeautifulSoup(content, 'html.parser')
    title = soup.find(class_="entry-title penci-entry-title penci-title-").text.strip() if soup.find(class_="entry-title penci-entry-title penci-title-") else None
    subtitle = soup.find(class_="entry-title penci-entry-title penci-title-").text.strip() if soup.find(class_="entry-title penci-entry-title penci-title-") else None
    date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

    news_paragraphs = soup.find(class_="penci-entry-content entry-content").find_all("p")
    # Accumulate the text from all news paragraphs
    main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

    news_data = {
        'url' : url,
        'title': title,
        'subtitle': subtitle,
        'date': date,
        'main_content': main_content
    }
    
    return news_data

def parseEMagazinNews(url, content):

    soup = BeautifulSoup(content, 'html.parser')
    title = soup.find(class_="entry-title penci-entry-title penci-title-").text.strip() if soup.find(class_="entry-title penci-entry-title penci-title-") else None
    subtitle = soup.find(class_="entry-title penci-entry-title penci-title-").text.strip() if soup.find(class_="entry-title penci-entry-title penci-title-") else None
    date = soup.find("time")["datetime"].strip() if soup.find("time")["datetime"] else None

    news_paragraphs = soup.find(class_="penci-entry-content entry-content").find_all("p")
    # Accumulate the text from all news paragraphs
    main_content = ' '.join(paragraph.get_text() for paragraph in news_paragraphs)

    news_data = {
        'url' : url,
        'title': title,
        'subtitle': subtitle,
        'date': date,
        'main_content': main_content
    }
    
    return news_data

# %%
from requests.exceptions import ConnectTimeout, ConnectionError
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
session = requests.Session()
retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])
adapter = HTTPAdapter(max_retries=retries)
session.mount('http://', adapter)
session.mount('https://', adapter)

successfully_accessed_sites = []
successfully_accessed_hostnames = []
unsuccessfully_accessed_sites = []

real_urls_list = []
parsedTexts = []

start_time = time.time()


for time_url in list_of_time_mk_urls:
    try:
          response = requests.get(time_url)
          # Gets the real url for each time.mk url.
          real_url = response.url
          real_urls_list.append(real_url)
          if response.status_code!=200:
                unsuccessfully_accessed_sites.append(real_url)
          else:
            successfully_accessed_sites.append(real_url)
            successfully_accessed_hostnames.append(urlparse(real_url).hostname)
            # Gets the html content for each response
            content = response.content
            # Gets the hostname for each url
            hostname = urlparse(real_url).hostname
            if hostname == "www.vecer.press":
                parsedTexts.append(parseVecerNews(real_url, content))
            elif hostname == "mk.tv21.tv":
                parsedTexts.append(parseTv21News(real_url, content))
            elif hostname == "360stepeni.mk":
                parsedTexts.append(parse360stepeni(real_url, content))
            elif hostname == "alfa.mk":
                parsedTexts.append(parseAlfaNews(real_url, content))
            elif hostname == "sitel.com.mk":
                parsedTexts.append(parseSitelNews(real_url, content))
            elif hostname == "sdk.mk":
                parsedTexts.append(parseSdkNews(real_url, content))
            elif hostname == "fokus.mk":
                parsedTexts.append(parseFokusNews(real_url, content))
            elif hostname == "sport1.mk":
                parsedTexts.append(parseSport1News(real_url, content))
            elif hostname == "kanal5.com.mk":
                parsedTexts.append(parseKanal5News(real_url, content))
            elif hostname == "republika.mk":
                parsedTexts.append(parseRepublikaNews(real_url, content))
            elif hostname == "puls24.mk":
                parsedTexts.append(parsePuls24News(real_url, content))
            elif hostname == "mkd.mk":
                parsedTexts.append(parseMkdNews(real_url, content))
            elif hostname == "novamakedonija.com.mk":
                parsedTexts.append(parseNovaMakedonijaNews(real_url, content))
            elif hostname == "alsat.mk":
                parsedTexts.append(parseAlsatNews(real_url, content))
            elif hostname == "www.slobodnaevropa.mk":
                parsedTexts.append(parseSlobodnaEvropaNews(real_url, content))
            elif hostname == "makfax.com.mk":
                parsedTexts.append(parseMakfaksNews(real_url, content))
            elif hostname == "mk.voanews.com":
                parsedTexts.append(parseMkVoaNews(real_url, content))
            elif hostname == "netpress.com.mk":
                parsedTexts.append(parseNetpressNews(real_url, content))
            elif hostname == "www.slobodenpecat.mk":
                parsedTexts.append(parseSlobodenPecatNews(real_url, content))
            elif hostname == "makpress.mk":
                parsedTexts.append(parseMakpressNews(real_url, content))
            elif hostname == "www.dw.com":
                parsedTexts.append(parseDWNews(real_url, content))
            elif hostname == "24.mk":
                parsedTexts.append(parse24MkNews(real_url, content))
            elif hostname == "www.radiomof.mk":
                parsedTexts.append(parseRadioMofNews(real_url, content))
            elif hostname == "centar.mk":
                parsedTexts.append(parseCentarMkNews(real_url, content))
            elif hostname == "a1on.mk":
                parsedTexts.append(parseA1OnNews(real_url, content))
            elif hostname == "telma.com.mk":
                parsedTexts.append(parseTelmaNews(real_url, content))
            elif hostname == "emagazin.mk":
                parsedTexts.append(parseEMagazinNews(real_url, content))
#             else:
#                 parsedTexts.append("Parse function for hostname " + hostname + " doesn't exist yet.")

    except (ConnectTimeout, ConnectionError) as e:
        print(f"Error connecting to {time_url}: {str(e)}")
        unsuccessfully_accessed_sites.append(time_url)
        continue
        
end_time = time.time()
total_time = end_time - start_time

print(f"The total time to parse all news sites is {total_time} seconds.")
# Out:
# The total time to parse all news sites is 115.91880917549133 seconds.

# %%
len(real_urls_list)
# Out:
# 60

# %%
print(len(successfully_accessed_sites))
print(len(successfully_accessed_hostnames))
print(len(unsuccessfully_accessed_sites))
# Out:
# 57
# 57
# 3

# %%
len(successfully_accessed_sites)
# Out:
# 57

# %%
len(parsedTexts)
# Out:
# 50

# %%
# parsedTexts

# %%
news_items = parsedTexts.copy()

# %%
for news_item in news_items:
    news_item['main_content'] = news_item['main_content'].replace('\n', '') if news_item['main_content'] != None else None
    news_item['main_content'] = news_item['main_content'].replace('\xa0', '') if news_item['main_content'] != None else None
    news_item['title'] = news_item['title'].replace('\xa0', '') if news_item['title'] != None else None
    news_item['subtitle'] = news_item['subtitle'].replace('\xa0', '') if news_item['subtitle'] != None else None

# %%
url_text_map = {}
for news_item in news_items:
  entry_url = news_item["url"]
  text = f"{news_item['title']}. {news_item['subtitle']}. {news_item['main_content']}"
  url_text_map[entry_url] = text

# %%
# !pip install transformers
# !pip install nlp
# !pip install sentencepiece
# !pip install torch
# !pip install spacy
# !pip install vaderSentiment
# !pip install textblob
# !pip install wordcloud matplotlib
# Out:
# Requirement already satisfied: transformers in c:\users\b5\anaconda3\lib\site-packages (4.32.0)
# Requirement already satisfied: filelock in c:\users\b5\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\b5\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\b5\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\b5\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\b5\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: colorama in c:\users\b5\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b5\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b5\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b5\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b5\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: nlp in c:\users\b5\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: numpy in c:\users\b5\anaconda3\lib\site-packages (from nlp) (1.24.3)
# Requirement already satisfied: pyarrow>=0.16.0 in c:\users\b5\anaconda3\lib\site-packages (from nlp) (11.0.0)
# Requirement already satisfied: dill in c:\users\b5\anaconda3\lib\site-packages (from nlp) (0.3.6)
# Requirement already satisfied: pandas in c:\users\b5\anaconda3\lib\site-packages (from nlp) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\b5\anaconda3\lib\site-packages (from nlp) (2.31.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\b5\anaconda3\lib\site-packages (from nlp) (4.65.0)
# Requirement already satisfied: filelock in c:\users\b5\anaconda3\lib\site-packages (from nlp) (3.9.0)
# Requirement already satisfied: xxhash in c:\users\b5\anaconda3\lib\site-packages (from nlp) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b5\anaconda3\lib\site-packages (from requests>=2.19.0->nlp) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b5\anaconda3\lib\site-packages (from requests>=2.19.0->nlp) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b5\anaconda3\lib\site-packages (from requests>=2.19.0->nlp) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b5\anaconda3\lib\site-packages (from requests>=2.19.0->nlp) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\b5\anaconda3\lib\site-packages (from tqdm>=4.27->nlp) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\b5\anaconda3\lib\site-packages (from pandas->nlp) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\b5\anaconda3\lib\site-packages (from pandas->nlp) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\b5\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->nlp) (1.16.0)
# Requirement already satisfied: sentencepiece in c:\users\b5\anaconda3\lib\site-packages (0.1.99)
# Requirement already satisfied: torch in c:\users\b5\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: filelock in c:\users\b5\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\b5\anaconda3\lib\site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in c:\users\b5\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\b5\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\b5\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\b5\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\b5\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: spacy in c:\users\b5\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (2.3.0)
# Requirement already satisfied: jinja2 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\b5\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\b5\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\b5\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\b5\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\b5\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b5\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b5\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b5\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b5\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\b5\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\b5\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.1)
# Requirement already satisfied: colorama in c:\users\b5\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\b5\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\b5\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: vaderSentiment in c:\users\b5\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\b5\anaconda3\lib\site-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\b5\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b5\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b5\anaconda3\lib\site-packages (from requests->vaderSentiment) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b5\anaconda3\lib\site-packages (from requests->vaderSentiment) (2023.7.22)
# Requirement already satisfied: textblob in c:\users\b5\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\b5\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\b5\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\b5\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\b5\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\b5\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\b5\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Requirement already satisfied: wordcloud in c:\users\b5\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: matplotlib in c:\users\b5\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\b5\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\b5\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\b5\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\b5\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !python -m spacy download en_core_web_sm

# %%
import transformers
import nlp
import torch
import spacy
from transformers import pipeline
from transformers import MarianMTModel, MarianTokenizer

import nltk
# nltk.download('punkt')

# %%
# Deprecated

# def chunk_text(text, tokenizer, max_length=1024):
#     # Split the text into sentences
#     sentences = nltk.sent_tokenize(text)
    
#     chunks = []
#     current_chunk = []
#     current_length = 0
    
#     for sentence in sentences:
#         # Tokenize the sentence to get its length
#         sentence_length = len(tokenizer.tokenize(sentence))
        
#         if current_length + sentence_length <= max_length:
#             current_chunk.append(sentence)
#             current_length += sentence_length
#         else:
#             chunks.append(" ".join(current_chunk))
#             current_chunk = [sentence]
#             current_length = sentence_length
    
#     if current_chunk:
#         chunks.append(" ".join(current_chunk))
    
#     return chunks

# %%
# # METHOD 1: Translate using MarianMT, A framework for translation models
# # Helsinki-NLP/opus-mt-mk-en

# # Load the pre-trained model and tokenizer
# model_name = "Helsinki-NLP/opus-mt-mk-en"
# model = MarianMTModel.from_pretrained(model_name)
# tokenizer = MarianTokenizer.from_pretrained(model_name)

# %%
# start_time = time.time()

# url_text_list = list(url_text_map.items())
# marian_translated_texts = {}
# for url_text in url_text_list[:1]:

#     # Define the input Macedonian text
    
#     input_url = url_text[0]
#     input_text = url_text[1]

#     # Split text into sentences using the Natural Language Toolkit Library
#     sentences = nltk.sent_tokenize(input_text)
    
#     # Translate each sentence separately
#     translated_sentences = []
#     for sentence in sentences:
#         input_ids = tokenizer.encode(sentence, return_tensors="pt")
#         with torch.no_grad():
#             translated_ids = model.generate(input_ids)
#         translated_sentence = tokenizer.decode(translated_ids[0], skip_special_tokens=True)
#         translated_sentences.append(translated_sentence)

#     # Combine translated sentences
#     translated_text = " ".join(translated_sentences)
#     marian_translated_texts[input_url] = translated_text
    
    
# end_time = time.time()
# total_time = end_time - start_time

# print(f"The total time to translate the text is {total_time} seconds.")

# %%
# marian_translated_texts

# %%
# !pip install googletrans==4.0.0rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0rc1 in c:\users\b5\anaconda3\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\b5\anaconda3\lib\site-packages (from googletrans==4.0.0rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2023.7.22)
# Requirement already satisfied: hstspreload in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2023.1.1)
# Requirement already satisfied: sniffio in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (1.2.0)
# Requirement already satisfied: chardet==3.* in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\b5\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\b5\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\b5\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\b5\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\b5\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1) (3.0.0)

# %%
# METHOD 2: Translate using Google Translate API
from googletrans import Translator
import time
import random

# Time and random are so that google doesn't block my IP address because of a large number of requests

start_time = time.time()
url_text_list = list(url_text_map.items())
google_translated_texts = {}
translator = Translator()
for url_text in url_text_list:
    translated_text = translator.translate(url_text[1][:5000], src='mk', dest='en').text
    google_translated_texts[url_text[0]] = translated_text
    time.sleep(random.uniform(0.02, 0.1))

end_time = time.time()
total_time = end_time - start_time

print(f"The total time to translate the text is {total_time} seconds.")
# Out:
# The total time to translate the text is 18.412167072296143 seconds.

# %%
len(google_translated_texts)
# Out:
# 46

# %%
# print(google_translated_texts)

# %%
# # METHOD 3: Translate using distilled version of the  Facebook Neural Language Model for Low-Resource Languages (NLLB-200)
# from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M", src_lang="mk_Cyrl")
# model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

# %%
# start_time = time.time()


# url_text_list = list(url_text_map.items())
# nllb_translated_texts = {}
# for url_text in url_text_list[:1]:
    
#     # Define the input Macedonian text
    
#     input_url = url_text[0]
#     input_text = url_text[1]
    
#     sentences = nltk.sent_tokenize(input_text)

#     translated_sentences = []
#     for sentence in sentences:
#         inputs = tokenizer(sentence, return_tensors="pt")
#         translated_tokens = model.generate(
#         **inputs, forced_bos_token_id=tokenizer.lang_code_to_id["eng_Latn"]
#         )
#         translated_sentence = tokenizer.decode(translated_tokens[0], skip_special_tokens=True)
#         translated_sentences.append(translated_sentence)
    
#     # Combine translated sentences
#     translated_text = " ".join(translated_sentences)
#     nllb_translated_texts[input_url] = translated_text
    
# end_time = time.time()
# total_time = end_time - start_time

# print(f"The total time to translate the text is {total_time} seconds.")

# %%
# nllb_translated_texts

# %%
# CONTINUE USING ONLY GOOGLE TRANSLATED TEXTS FOR BEST ACCURACY

# %%
# Function to aggregate the sentiment for a single entity, since a single entity will have multiple sentiments
# if the entity is present in multiple sentences.
# sentiments contains a list of all the sentiments for a single entity that were gathered from the text

def aggregate_sentiment(sentiments, entity_type):
    # Initialize counters
    total_positive = 0
    total_negative = 0
    count_positive = 0
    count_negative = 0
    
    for sentiment in sentiments:
        if sentiment['label'] == 'POSITIVE':
            total_positive += sentiment['score']
            count_positive += 1
        elif sentiment['label'] == 'NEGATIVE':
            total_negative += sentiment['score']
            count_negative += 1
            


    if total_positive > total_negative:
        return {'type': entity_type, 'label': 'POSITIVE', 'total_positive': total_positive, 'total_negative': total_negative, 'count_positive': count_positive, 'count_negative': count_negative}
    else:
        return {'type': entity_type, 'label': 'NEGATIVE', 'total_positive': total_positive, 'total_negative': total_negative, 'count_positive': count_positive, 'count_negative': count_negative}

# %%
# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Define sentiment analysis pipeline using transformers
# sentiment_pipeline = pipeline("sentiment-analysis", model="siebert/sentiment-roberta-large-english")
sentiment_pipeline = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")

# Extracts entities and sentiment for a single text
def extract_entities_and_sentiment(text):
    doc = nlp(text)
    
    # Store entity sentiments
    entity_sentiments = {}
    
    # Store sentences and entity label for each entity
    entity_sentences = {}
    
    for ent in doc.ents:
        if ent.text not in entity_sentences:
            entity_sentences[ent.text] = {"sentences": [ent.sent.text], "entity_type": ent.label_}
        else:
            entity_sentences[ent.text]["sentences"].append(ent.sent.text)
            
    for entity, info in entity_sentences.items():
        sentiments = []
        for sentence in info["sentences"]:
            sentiment = sentiment_pipeline(sentence)
            sentiments.append(sentiment[0])
        
        entity_sentiments[entity] = aggregate_sentiment(sentiments, info["entity_type"])

    return entity_sentiments

# %%
entity_sentiments = []
google_translated_texts_list = list(google_translated_texts.items())
url_sentiments = []
for url_translated_text in google_translated_texts_list:
    entity_sentiments = extract_entities_and_sentiment(url_translated_text[1])
    url_sentiments.append([url_translated_text[0], entity_sentiments])

# %%
url_sentiments
# Out:
# [['https://24.mk/details/brojot-na-zarazeni-so-koronavirus-760-lica-manu-prognozira-pikot-da-bide-na-pochetok-na-maj-so-1-100',
#   {'760': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 3.865076005458832,
#     'count_positive': 0,
#     'count_negative': 4},
#    'MANU': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0.9506388306617737,
#     'total_negative': 3.852744162082672,
#     'count_positive': 1,
#     'count_negative': 4},
#    'the beginning of May': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 2.9239572882652283,
#     'count_positive': 0,
#     'count_negative': 3},
#    '49': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9757880568504333,
#     'count_positive': 0,
#     'count_negative': 1},
#    'yesterday': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 3.8731754422187805,
#     'count_positive': 0,
#     'count_negative': 4},
#    'two': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9757880568504333,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the New Year': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '13': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Skopje': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0.8965880870819092,
#     'count_positive': 1,
#     'count_negative': 1},
#    '14': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Kumanovo': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0.9872943758964539,
#     'count_positive': 1,
#     'count_negative': 1},
#    'six': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 1.9166909456253052,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'Stip': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'eight': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Prilep': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0.9872943758964539,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Veles': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'one': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Gostivar': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Kocani': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9583454728126526,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'The Ministry of Health': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9872943758964539,
#     'count_positive': 0,
#     'count_negative': 1},
#    '73 years': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9872943758964539,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Clinic for Infectious Diseases': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9872943758964539,
#     'count_positive': 0,
#     'count_negative': 1},
#    'April 1': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9872943758964539,
#     'count_positive': 0,
#     'count_negative': 1},
#    '76 years': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9872943758964539,
#     'count_positive': 0,
#     'count_negative': 1},
#    '15:00': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9377118349075317,
#     'count_positive': 0,
#     'count_negative': 1},
#    '41': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9377118349075317,
#     'count_positive': 0,
#     'count_negative': 1},
#    '34': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9377118349075317,
#     'count_positive': 0,
#     'count_negative': 1},
#    '685': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9377118349075317,
#     'count_positive': 0,
#     'count_negative': 1},
#    '7,653': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8453196287155151,
#     'count_positive': 0,
#     'count_negative': 1},
#    '297': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8965880870819092,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kumanovo-18': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8965880870819092,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Stip-27': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8965880870819092,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Ohrid': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8965880870819092,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gostivar -7': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8965880870819092,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kriva': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8965880870819092,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kocani-20': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8965880870819092,
#     'count_positive': 0,
#     'count_negative': 1},
#    'late April': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0.915087878704071,
#     'total_negative': 0.9723811745643616,
#     'count_positive': 1,
#     'count_negative': 1},
#    'April': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9723811745643616,
#     'count_positive': 0,
#     'count_negative': 1},
#    'about 1,100': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9723811745643616,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Ljupco Kocarev': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9506388306617737,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Petar Jovanovski': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9506388306617737,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'about 2,000': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.915087878704071,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Imperial College': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9287868738174438,
#     'count_positive': 0,
#     'count_negative': 1},
#    'London': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9287868738174438,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Oxford University': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9287868738174438,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://24.mk/details/novi-103-amerikanski-vojnici-od-nosach-na-avioni-pozitivni-na-kovid-19',
#   {'US': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 1.7138932943344116,
#     'total_negative': 0.9830484390258789,
#     'count_positive': 2,
#     'count_negative': 1},
#    '103': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0.8569466471672058,
#     'total_negative': 0.9830484390258789,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Theodore Roosevelt': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9830484390258789,
#     'count_positive': 0,
#     'count_negative': 1},
#    '550': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9830484390258789,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the US Navy': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9830484390258789,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Navy': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9167381525039673,
#     'count_positive': 0,
#     'count_negative': 1},
#    '92 percent': {'type': 'PERCENT',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9167381525039673,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://fokus.mk/mz-patsientite-so-retki-bolesti-nema-da-ostanat-bez-lekovi/',
#   {'The Ministry of Health': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9657553434371948,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the months of April': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9657553434371948,
#     'count_positive': 0,
#     'count_negative': 1},
#    'May and June': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9657553434371948,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kovid - 19': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.7075835466384888,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the coming period': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.7075835466384888,
#     'count_positive': 0,
#     'count_negative': 1},
#    '2-3 months': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9066985249519348,
#     'count_positive': 0,
#     'count_negative': 1},
#    'June 2020.As of March 2020': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8657709360122681,
#     'count_positive': 0,
#     'count_negative': 1},
#    '530': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8657709360122681,
#     'count_positive': 0,
#     'count_negative': 1},
#    'over 150': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9588925838470459,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Health Insurance Fund': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9588925838470459,
#     'count_positive': 0,
#     'count_negative': 1},
#    '2015': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'about 96': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '2018': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'about 140': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '2019': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0.9480733275413513,
#     'count_positive': 1,
#     'count_negative': 1},
#    'about 170': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '2020': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0.9923068881034851,
#     'count_positive': 1,
#     'count_negative': 1},
#    '185': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '+ 150': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.8972389101982117,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '35': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9923068881034851,
#     'count_positive': 0,
#     'count_negative': 1},
#    '3': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9923068881034851,
#     'count_positive': 0,
#     'count_negative': 1},
#    'third': {'type': 'ORDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 2.873344838619232,
#     'count_positive': 0,
#     'count_negative': 3},
#    'Goshe': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9923068881034851,
#     'count_positive': 0,
#     'count_negative': 1},
#    '4': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9923068881034851,
#     'count_positive': 0,
#     'count_negative': 1},
#    '2017': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.888731062412262,
#     'count_positive': 0,
#     'count_negative': 1},
#    'today': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.888731062412262,
#     'count_positive': 0,
#     'count_negative': 1},
#    '9': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.888731062412262,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Esenmenger Syndrome': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9480733275413513,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Bosentan': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.990708589553833,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://mk.voanews.com/a/5369041.html',
#   {'Easter': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 1.7399382591247559,
#     'total_negative': 1.9917331337928772,
#     'count_positive': 2,
#     'count_negative': 2},
#    'today': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6175117492675781,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Health': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6175117492675781,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Venko Filipce': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6175117492675781,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Friday': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 2.490404427051544,
#     'count_positive': 0,
#     'count_negative': 3},
#    'Tuesday': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.5595714449882507,
#     'count_positive': 0,
#     'count_negative': 2},
#    'morning': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.5595714449882507,
#     'count_positive': 0,
#     'count_negative': 2},
#    'the Commission for Infectious Diseases': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9880191683769226,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'tomorrow': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 1.9725695848464966,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'next weekend': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.984550416469574,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the following week': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.984550416469574,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'one': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0.9760090112686157,
#     'total_negative': 1.9023213982582092,
#     'count_positive': 1,
#     'count_negative': 2},
#    'the days': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9760090112686157,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the weekend': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9760090112686157,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Monday': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9952371120452881,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'this weekend': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9952371120452881,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Filipce': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0.9952371120452881,
#     'total_negative': 0.9954105019569397,
#     'count_positive': 1,
#     'count_negative': 1},
#    '4 pm': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9308329820632935,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Monday to 5am': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9308329820632935,
#     'count_positive': 0,
#     'count_negative': 1},
#    '61 hours': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9308329820632935,
#     'count_positive': 0,
#     'count_negative': 1},
#    'The Ministry of Health': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9448354244232178,
#     'count_positive': 0,
#     'count_negative': 1},
#    '68': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9448354244232178,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the past 24 hours': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9448354244232178,
#     'count_positive': 0,
#     'count_negative': 1},
#    '828': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9733477830886841,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Skopje': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9638990163803101,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Kumanovo': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9638990163803101,
#     'total_negative': 0.9418497085571289,
#     'count_positive': 1,
#     'count_negative': 1},
#    '119': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9904332160949707,
#     'count_positive': 0,
#     'count_negative': 1},
#    '14': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9904332160949707,
#     'count_positive': 0,
#     'count_negative': 1},
#    'ninety': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9904332160949707,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Infectious Disease Clinic': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.8091190457344055,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '69': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.8091190457344055,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the September 8th City Hospital': {'type': 'EVENT',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9892332553863525,
#     'count_positive': 0,
#     'count_negative': 1},
#    '9': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9892332553863525,
#     'count_positive': 0,
#     'count_negative': 1},
#    '31': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9892332553863525,
#     'count_positive': 0,
#     'count_negative': 1},
#    '6': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9767204523086548,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Bitola': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.877600610256195,
#     'count_positive': 0,
#     'count_negative': 2},
#    '8': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9874871969223022,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Stip': {'type': 'WORK_OF_ART',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9874871969223022,
#     'count_positive': 0,
#     'count_negative': 1},
#    '13': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9874871969223022,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Ministry': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9874871969223022,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the last 24 hours': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9460994601249695,
#     'count_positive': 0,
#     'count_negative': 1},
#    '404': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9460994601249695,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Institute of Public Health': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9839909076690674,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'IPH': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9839909076690674,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Avicenna': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9839909076690674,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Biotek -24': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9839909076690674,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Philip II': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9839909076690674,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '8,057': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.608300507068634,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kovid -19': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.608300507068634,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Skopje - 312': {'type': 'PRODUCT',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.751339316368103,
#     'count_positive': 0,
#     'count_negative': 1},
#    '200': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9418497085571289,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Prilep - 72': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9418497085571289,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Debar': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9971575736999512,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the ninth day': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9971575736999512,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Strumica': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.8911392092704773,
#     'count_positive': 0,
#     'count_negative': 2},
#    '43': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9308775067329407,
#     'count_positive': 0,
#     'count_negative': 1},
#    '33': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9308775067329407,
#     'count_positive': 0,
#     'count_negative': 1},
#    '30': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9308775067329407,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Veles': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9308775067329407,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Stip - 27': {'type': 'FAC',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.7646800875663757,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kocani': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.7646800875663757,
#     'count_positive': 0,
#     'count_negative': 1},
#    '21': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.7646800875663757,
#     'count_positive': 0,
#     'count_negative': 1},
#    'nine': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8901134133338928,
#     'count_positive': 0,
#     'count_negative': 1},
#    'eight': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8901134133338928,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gostivar': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8901134133338928,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Radovis': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8901134133338928,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Ohrid': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8901134133338928,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Gevgelija': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8901134133338928,
#     'count_positive': 0,
#     'count_negative': 1},
#    'four': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8901134133338928,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kriva Palanka': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9602617025375366,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Krusevo': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9602617025375366,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kavadarci': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9602617025375366,
#     'count_positive': 0,
#     'count_negative': 1},
#    'three': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9602617025375366,
#     'count_positive': 0,
#     'count_negative': 1},
#    'two': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9602617025375366,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Probistip': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9602617025375366,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://kanal5.com.mk/ojo-skopje-podnese-20-kazneni-nalozi-za-nepochituvanje-na-policiskiot-chas/a417283',
#   {'20': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 2.8496066331863403,
#     'count_positive': 0,
#     'count_negative': 3},
#    "The Basic Public Prosecutor's Office Skopje": {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.869502067565918,
#     'count_positive': 0,
#     'count_negative': 1},
#    'today': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.869502067565918,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Republic of Macedonia': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9487754106521606,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Skopje Basic Criminal Court': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9930658340454102,
#     'count_positive': 0,
#     'count_negative': 1},
#    '100': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9930658340454102,
#     'count_positive': 0,
#     'count_negative': 1},
#    'daily': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9861316680908203,
#     'count_positive': 0,
#     'count_negative': 2},
#    'one': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9930658340454102,
#     'count_positive': 0,
#     'count_negative': 1},
#    'denar counter -value': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9930658340454102,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://kanal5.com.mk/delchevci-aplaudiraa-za-poddrshka-na-zdravstvenite-rabotnici-i-site-koi-davaat-svoj-pridones-vo-borbata-protiv-kovid-19/a417559',
#   {'Kovid-19.Delchevci': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9996598958969116,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'last night': {'type': 'TIME',
#     'label': 'POSITIVE',
#     'total_positive': 0.9996598958969116,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Coronavirus': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6034532785415649,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Today': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9921938180923462,
#     'total_negative': 0.9849253296852112,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Delcevo': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9989245533943176,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'China': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9844308495521545,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Italy': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9926855564117432,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Paris': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9994943141937256,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'London': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9994943141937256,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Delchevo': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9659911394119263,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'one': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9659911394119263,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'yesterday': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9973651766777039,
#     'count_positive': 0,
#     'count_negative': 1},
#    'three': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9921938180923462,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'first': {'type': 'ORDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9921938180923462,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '14': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9921938180923462,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Strumica': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9921938180923462,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Bitola./MIA': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9921938180923462,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://24.mk/details/sonchevo-so-umeren-do-zasilen-jugoistochen-veter',
#   {'Poncevo': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9881846904754639,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the day': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9881846904754639,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Povardarie': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9881846904754639,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the afternoon': {'type': 'TIME',
#     'label': 'POSITIVE',
#     'total_positive': 0.9370649456977844,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Morning': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0.8356375098228455,
#     'total_negative': 0.8649957776069641,
#     'count_positive': 1,
#     'count_negative': 1},
#    'zero': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8649957776069641,
#     'count_positive': 0,
#     'count_negative': 1},
#    'seven degrees': {'type': 'QUANTITY',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8649957776069641,
#     'count_positive': 0,
#     'count_negative': 1},
#    'daytime': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8649957776069641,
#     'count_positive': 0,
#     'count_negative': 1},
#    '14': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.8649957776069641,
#     'count_positive': 0,
#     'count_negative': 1},
#    '22 degrees': {'type': 'QUANTITY',
#     'label': 'NEGATIVE',
#     'total_positive': 0.8356375098228455,
#     'total_negative': 0.8649957776069641,
#     'count_positive': 1,
#     'count_negative': 1},
#    'Skopje': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9991208910942078,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'five degrees and daytime': {'type': 'QUANTITY',
#     'label': 'POSITIVE',
#     'total_positive': 0.8356375098228455,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://www.slobodnaevropa.mk/a/30545357.html',
#   {'Hungary': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 3.916235387325287,
#     'count_positive': 0,
#     'count_negative': 4},
#    'Viktor Orban': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9903558492660522,
#     'count_positive': 0,
#     'count_negative': 1},
#    'last night': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9903558492660522,
#     'count_positive': 0,
#     'count_negative': 1},
#    '980': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9577042460441589,
#     'count_positive': 0,
#     'count_negative': 1},
#    '66': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9577042460441589,
#     'count_positive': 0,
#     'count_negative': 1},
#    'April 11.Orban': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.99402916431427,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Easter': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.99402916431427,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Last week': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9511724710464478,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Hungary Parliament': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9511724710464478,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Orban': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9511724710464478,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://360stepeni.mk/mitskoski-ministerstvoto-za-finansii-prifatilo-del-od-predlozite-na-vmro-dpmne-video/',
#   {'Mickoski: The Ministry of Finance': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9859039187431335,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'VMRO-DPMNE': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 1.971807837486267,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'The Ministry of Finance': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9859039187431335,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Macedonian': {'type': 'NORP',
#     'label': 'NEGATIVE',
#     'total_positive': 0.9859039187431335,
#     'total_negative': 1.891023337841034,
#     'count_positive': 1,
#     'count_negative': 2},
#    '50 percent': {'type': 'PERCENT',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9925376772880554,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Christian Mickoski': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9925376772880554,
#     'count_positive': 0,
#     'count_negative': 1},
#    'today': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 1.9366921782493591,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'the Ministry of Finance': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 1.9366921782493591,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'Decree': {'type': 'NORP',
#     'label': 'POSITIVE',
#     'total_positive': 0.9446172118186951,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Nake Zulev': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9446172118186951,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Government': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 1.807476818561554,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    'Oliver Spasovski': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9446172118186951,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Mickoski': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 1.9440813064575195,
#     'total_negative': 2.9157840609550476,
#     'count_positive': 2,
#     'count_negative': 3},
#    'July': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9936966300010681,
#     'count_positive': 0,
#     'count_negative': 1},
#    'September': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9936966300010681,
#     'count_positive': 0,
#     'count_negative': 1},
#    'second': {'type': 'ORDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9810450077056885,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the beginning of this year': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9249643683433533,
#     'count_positive': 0,
#     'count_negative': 1},
#    'three': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 1.998928189277649,
#     'total_negative': 0,
#     'count_positive': 2,
#     'count_negative': 0},
#    '2021.Secondly': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9979726672172546,
#     'count_positive': 0,
#     'count_negative': 1},
#    'March': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0.8628596067428589,
#     'total_negative': 0.9979726672172546,
#     'count_positive': 1,
#     'count_negative': 1},
#    'third': {'type': 'ORDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9569222331047058,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://mk.tv21.tv/najnova-sostojba-so-koronavirusot-vo-makedonija-dve-litsa-pochinati-novi-37-sluchai-izlekuvani-15-patsienti/',
#   {'Macedonia': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9583015441894531,
#     'count_positive': 0,
#     'count_negative': 2},
#    'two': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9583015441894531,
#     'count_positive': 0,
#     'count_negative': 2},
#    '37': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9583015441894531,
#     'count_positive': 0,
#     'count_negative': 2},
#    '15': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 3.814348340034485,
#     'count_positive': 0,
#     'count_negative': 4},
#    'The Ministry of Health': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9311572909355164,
#     'count_positive': 0,
#     'count_negative': 1},
#    'today': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9311572909355164,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Institute of Public Health': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9311572909355164,
#     'count_positive': 0,
#     'count_negative': 1},
#    '6': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9311572909355164,
#     'count_positive': 0,
#     'count_negative': 1},
#    '9': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9311572909355164,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Two': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9782076478004456,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Skopje': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.592829167842865,
#     'count_positive': 0,
#     'count_negative': 2},
#    'the age of 66': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9782076478004456,
#     'count_positive': 0,
#     'count_negative': 1},
#    'CS': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9782076478004456,
#     'count_positive': 0,
#     'count_negative': 1},
#    'September 8': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0.9719122648239136,
#     'total_negative': 0.9782076478004456,
#     'count_positive': 1,
#     'count_negative': 1},
#    'the Clinic for Infectious Diseases': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9782076478004456,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Stip': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9648644924163818,
#     'count_positive': 0,
#     'count_negative': 2},
#    'the age of 83': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9782076478004456,
#     'count_positive': 0,
#     'count_negative': 1},
#    'comorbidities.-19.In': {'type': 'NORP',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9782076478004456,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Skopje-409\uf0a7 Kumanovo-329enc': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9782076478004456,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Stip-32\uf0a7 Prilep': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9782901406288147,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Bitola -17 \uf0a7': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9769182801246643,
#     'count_positive': 0,
#     'count_negative': 1},
#    '1': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 2.951875925064087,
#     'total_negative': 0,
#     'count_positive': 3,
#     'count_negative': 0},
#    'Kriva Palanka': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9737180471420288,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Radovis -4\uf0a7 Krushevo -3\uf0a7 Kocani -27 \uf0a7': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9737180471420288,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Demir Hisar': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9876198768615723,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Makedonski Brod': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9788642525672913,
#     'count_positive': 0,
#     'count_negative': 1},
#    '24 hours': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9788642525672913,
#     'count_positive': 0,
#     'count_negative': 1},
#    'IPH': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9700110554695129,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Tet -0': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9700110554695129,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Avicenna': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9700110554695129,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Biotek -27': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9700110554695129,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Philip II': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9700110554695129,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Sistina': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9700110554695129,
#     'count_positive': 0,
#     'count_negative': 1},
#    'PCR': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9700110554695129,
#     'count_positive': 0,
#     'count_negative': 1},
#    '11870': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6146215200424194,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kovid -19': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6146215200424194,
#     'count_positive': 0,
#     'count_negative': 1},
#    '8': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6146215200424194,
#     'count_positive': 0,
#     'count_negative': 1},
#    '55': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9840201139450073,
#     'count_positive': 0,
#     'count_negative': 1},
# ...
#     'total_negative': 0.9994872808456421,
#     'count_positive': 0,
#     'count_negative': 1},
#    'mid-March': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9994872808456421,
#     'count_positive': 0,
#     'count_negative': 1},
#    '26,621': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9777126312255859,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://fokus.mk/janeva-da-znaete-shto-znam-jas-od-tie-660-iljadi-razgovori-sigurno-ne-bi-bila-na-ova-mesto/',
#   {'660,000': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 2.9916844964027405,
#     'count_positive': 0,
#     'count_negative': 3},
#    'Katica Janeva': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9992316961288452,
#     'count_positive': 0,
#     'count_negative': 1},
#    'today': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9992316961288452,
#     'count_positive': 0,
#     'count_negative': 1},
#    'over 660,000': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9992316961288452,
#     'count_positive': 0,
#     'count_negative': 1},
#    "the Special Prosecutor's Office": {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9992316961288452,
#     'count_positive': 0,
#     'count_negative': 1},
#    'SPO': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.980169951915741,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Janeva': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9899160265922546,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://kanal5.com.mk/vo-germanija-ushte-33-pochinati-i-583-novozarazeni-od-kovid-19/a422455',
#   {'Germany': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.936153531074524,
#     'count_positive': 0,
#     'count_negative': 2},
#    '33': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9335318207740784,
#     'count_positive': 0,
#     'count_negative': 2},
#    '583': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.936153531074524,
#     'count_positive': 0,
#     'count_negative': 2},
#    'the last 24 hours': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.968076765537262,
#     'count_positive': 0,
#     'count_negative': 1},
#    '174,355': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.968076765537262,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the Robert Koch Institute': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.968076765537262,
#     'count_positive': 0,
#     'count_negative': 1},
#    '7,914': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9654550552368164,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Reuters': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9654550552368164,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://fokus.mk/zaev-izbori-najbrzo-shto-mozhe-nema-da-ima-ultimatum-za-datumot/',
#   {'Zaev': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 1.9908037185668945,
#     'total_negative': 1.9910824298858643,
#     'count_positive': 2,
#     'count_negative': 2},
#    'first': {'type': 'ORDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.937147319316864,
#     'count_positive': 0,
#     'count_negative': 3},
#    'SDSM': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.351441740989685,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Zoran Zaev': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.7657361626625061,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Sitel': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.7657361626625061,
#     'count_positive': 0,
#     'count_negative': 1},
#    'June 21': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9984921216964722,
#     'count_positive': 0,
#     'count_negative': 1},
#    '28': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9984921216964722,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Borders': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.997353196144104,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'July': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 0.997353196144104,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://kanal5.com.mk/vmro-dpmne-sdsm-zoran-zaev-i-venko-filipche-rabotat-na-shteta-na-zdravjeto-na-gragjanite/a422448',
#   {'Zoran Zaev': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9556682109832764,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Venko Filipce': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9556682109832764,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Zaev': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0.9611461758613586,
#     'total_negative': 2.8432978987693787,
#     'count_positive': 1,
#     'count_negative': 3},
#    'SDSM': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.8522053956985474,
#     'count_positive': 0,
#     'count_negative': 2},
#    'Citizens': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9967063069343567,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Only yesterday': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9922203421592712,
#     'count_positive': 0,
#     'count_negative': 1},
#    '22': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9922203421592712,
#     'count_positive': 0,
#     'count_negative': 1},
#    'one': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9922203421592712,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Filipce': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.843623697757721,
#     'count_positive': 0,
#     'count_negative': 2},
#    'the Republic of Macedonia': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9609431624412537,
#     'count_positive': 0,
#     'count_negative': 2},
#    '9034': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9698506593704224,
#     'count_positive': 0,
#     'count_negative': 1},
#    '2 million': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9698506593704224,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Slovenia': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9698506593704224,
#     'count_positive': 0,
#     'count_negative': 1},
#    '30221': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9698506593704224,
#     'count_positive': 0,
#     'count_negative': 1},
#    '1 million': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9698506593704224,
#     'count_positive': 0,
#     'count_negative': 1},
#    'The Republic of Macedonia': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9981451034545898,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Kovid': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9981451034545898,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    '19': {'type': 'CARDINAL',
#     'label': 'POSITIVE',
#     'total_positive': 0.9981451034545898,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Albania': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9981451034545898,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Bulgaria': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9981451034545898,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'Greece': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9981451034545898,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'VMRO-DPMNE': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9985721111297607,
#     'count_positive': 0,
#     'count_negative': 1},
#    "Zoran Zaev's": {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9985721111297607,
#     'count_positive': 0,
#     'count_negative': 1},
#    'SDSM.With SDSM': {'type': 'GPE',
#     'label': 'POSITIVE',
#     'total_positive': 0.9611461758613586,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    "VMRO-DPMNE's": {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9083111882209778,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://kanal5.com.mk/sdsm-propadnatiot-mickoski-se-plashi-od-gragjanite-i-zatoa-bega-od-izbori/a422447',
#   {'Mickoski': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 3.995248556137085,
#     'count_positive': 0,
#     'count_negative': 4},
#    'SDSM': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9964421391487122,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0}}],
#  ['https://24.mk/details/vo-izminatite-24-chasa-napraveni-se-426-testiranja-a-registrirani-se-30-novi-sluchai-na-kovid-19',
#   {'the past 24 hours': {'type': 'TIME',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.8786964416503906,
#     'count_positive': 0,
#     'count_negative': 2},
#    '426': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.8786964416503906,
#     'count_positive': 0,
#     'count_negative': 2},
#    '30': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.8786964416503906,
#     'count_positive': 0,
#     'count_negative': 2}}],
#  ['https://kanal5.com.mk/novi-14-dena-vonredna-sostojba-za-zaokruzhuvanje-na-zdravstvenite-odgovori-na-pandemijata/a422358',
#   {'14 days': {'type': 'DATE',
#     'label': 'POSITIVE',
#     'total_positive': 1.8748478293418884,
#     'total_negative': 1.591086745262146,
#     'count_positive': 2,
#     'count_negative': 2},
#    'third': {'type': 'ORDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0.611910343170166,
#     'total_negative': 0.9428346157073975,
#     'count_positive': 1,
#     'count_negative': 1},
#    'March 18': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0.611910343170166,
#     'total_negative': 0.9428346157073975,
#     'count_positive': 1,
#     'count_negative': 1},
#    'yesterday': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6206487417221069,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the State PresidentStevo Pendarovski': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6206487417221069,
#     'count_positive': 0,
#     'count_negative': 1},
#    '30 days': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.6206487417221069,
#     'count_positive': 0,
#     'count_negative': 1},
#    '30': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.939422369003296,
#     'count_positive': 0,
#     'count_negative': 2},
#    'today': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.885669231414795,
#     'count_positive': 0,
#     'count_negative': 2},
#    'May 16': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9428346157073975,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Security Council': {'type': 'ORG',
#     'label': 'POSITIVE',
#     'total_positive': 0.9958286881446838,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'only 14 days': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9965877532958984,
#     'count_positive': 0,
#     'count_negative': 1},
#    'the beginning of next week': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9704380035400391,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Pendarovski': {'type': 'PERSON',
#     'label': 'POSITIVE',
#     'total_positive': 0.9874080419540405,
#     'total_negative': 0,
#     'count_positive': 1,
#     'count_negative': 0},
#    'the Constitutional Court': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.999342143535614,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Kovid': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.890367329120636,
#     'count_positive': 0,
#     'count_negative': 1},
#    '1,740': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.890367329120636,
#     'count_positive': 0,
#     'count_negative': 1},
#    '97': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.890367329120636,
#     'count_positive': 0,
#     'count_negative': 1},
#    '392./mia': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.890367329120636,
#     'count_positive': 0,
#     'count_negative': 1}}],
#  ['https://24.mk/details/gunzburg-rusija-do-krajot-na-letoto-kje-ja-registrira-vakcinata-protiv-koronavirusot',
#   {'Gunzburg': {'type': 'PERSON',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 3.1057719588279724,
#     'count_positive': 0,
#     'count_negative': 4},
#    'Russia': {'type': 'GPE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 3.104496419429779,
#     'count_positive': 0,
#     'count_negative': 4},
#    'the end of the summer': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 2.114341676235199,
#     'count_positive': 0,
#     'count_negative': 3},
#    'August': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 1.9693101048469543,
#     'count_positive': 0,
#     'count_negative': 2},
#    'the National Research Center for Epidemiology and Microbiology': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9791553616523743,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Alexander Gunzburg.-I': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9791553616523743,
#     'count_positive': 0,
#     'count_negative': 1},
#    '1': {'type': 'CARDINAL',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9901547431945801,
#     'count_positive': 0,
#     'count_negative': 1},
#    'TASS': {'type': 'ORG',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9901547431945801,
#     'count_positive': 0,
#     'count_negative': 1},
#    'another month': {'type': 'DATE',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9964374303817749,
#     'count_positive': 0,
#     'count_negative': 1},
#    'Russians': {'type': 'NORP',
#     'label': 'NEGATIVE',
#     'total_positive': 0,
#     'total_negative': 0.9804309010505676,
#     'count_positive': 0,
#     'count_negative': 1}}]]

# %%
# THE FINAL RESULT UNTIL NOW IS url_sentiments: List of [url, entity_sentiments: map of key entity and value sentiment]

# %%
def get_hostname(url):
    return urlparse(url).hostname

# This function is used to merge the list of entity_sentiment of two urls that have the same hostname
# entity_sentiments1, entity_sentiments2 are maps with key entity and value sentiment
def merge_sentiments(entity_sentiments1, entity_sentiments2):
    for entity, sentiment_values in entity_sentiments2.items():
        if entity not in entity_sentiments1:
            entity_sentiments1[entity] = sentiment_values
        else:
            for key, value in sentiment_values.items():
                if key.startswith('total_') or key.startswith('count_'):
                    entity_sentiments1[entity][key] += value
               
    return entity_sentiments1

# %%
# Transform from url_sentiments list to hostname_sentiments list
# Merge the sentiment values for the same entity
# Append the sentiment values for new entities
hostname_sentiments = {}

for url, sentiments in url_sentiments:
    hostname = get_hostname(url)
    if hostname not in hostname_sentiments:
        hostname_sentiments[hostname] = sentiments
    else:
        hostname_sentiments[hostname] = merge_sentiments(hostname_sentiments[hostname], sentiments)

# Convert the dictionary back to a list
hostname_sentiments_list = [[hostname, sentiments] for hostname, sentiments in hostname_sentiments.items()]


# Calculate average score for each entity for each hostname

for hostname, sentiments in hostname_sentiments_list:
    for entity, sentiment in sentiments.items():
        if sentiment['label'] == 'POSITIVE':
            sentiment['score'] = sentiment['total_positive'] / sentiment['count_positive']
        else:
            sentiment['score'] = sentiment['total_negative'] / sentiment['count_negative']

print(hostname_sentiments_list)
# Out:
# [['24.mk', {'760': {'type': 'CARDINAL', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative': 3.865076005458832, 'count_positive': 0, 'count_negative': 4, 'score': 0.966269001364708}, 'MANU': {'type': 'ORG', 'label': 'NEGATIVE', 'total_positive': 0.9506388306617737, 'total_negative': 3.852744162082672, 'count_positive': 1, 'count_negative': 4, 'score': 0.963186040520668}, 'the beginning of May': {'type': 'DATE', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative': 2.9239572882652283, 'count_positive': 0, 'count_negative': 3, 'score': 0.9746524294217428}, '49': {'type': 'CARDINAL', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative': 0.9757880568504333, 'count_positive': 0, 'count_negative': 1, 'score': 0.9757880568504333}, 'yesterday': {'type': 'DATE', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative': 3.8731754422187805, 'count_positive': 0, 'count_negative': 4, 'score': 0.9682938605546951}, 'two': {'type': 'CARDINAL', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative': 0.9757880568504333, 'count_positive': 0, 'count_negative': 1, 'score': 0.9757880568504333}, 'the New Year': {'type': 'DATE', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9583454728126526}, '13': {'type': 'CARDINAL', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9583454728126526}, 'Skopje': {'type': 'GPE', 'label': 'POSITIVE', 'total_positive': 1.9574663639068604, 'total_negative': 0.8965880870819092, 'count_positive': 2, 'count_negative': 1, 'score': 0.9787331819534302}, '14': {'type': 'DATE', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0.8649957776069641, 'count_positive': 1, 'count_negative': 1, 'score': 0.9583454728126526}, 'Kumanovo': {'type': 'GPE', 'label': 'NEGATIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0.9872943758964539, 'count_positive': 1, 'count_negative': 1, 'score': 0.9872943758964539}, 'six': {'type': 'CARDINAL', 'label': 'POSITIVE', 'total_positive': 1.9166909456253052, 'total_negative': 0, 'count_positive': 2, 'count_negative': 0, 'score': 0.9583454728126526}, 'Stip': {'type': 'GPE', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9583454728126526}, 'eight': {'type': 'CARDINAL', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9583454728126526}, 'Prilep': {'type': 'PERSON', 'label': 'NEGATIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0.9872943758964539, 'count_positive': 1, 'count_negative': 1, 'score': 0.9872943758964539}, 'Veles': {'type': 'GPE', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9583454728126526}, 'one': {'type': 'CARDINAL', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9583454728126526}, 'Gostivar': {'type': 'GPE', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9583454728126526}, 'Kocani': {'type': 'GPE', 'label': 'POSITIVE', 'total_positive': 0.9583454728126526, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9583454728126526}, 'The Ministry of Health': {'type': 'ORG', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative': 0.9872943758964539, 'count_positive': 0, 'count_negative': 1, 'score': 0.9872943758964539}, '73 years': {'type': 'DATE', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative': 0.9872943758964539, 'count_positive': 0, 'count_negative': 1, 'score': 0.9872943758964539}, 'the Clinic for Infectious Diseases': {'type': 'ORG', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative ...

# %%
# print("Max index that can be set as hostname_index is " + str(len(hostname_sentiments_list) - 1))

# %%
i=0
for hostname, sentiment in hostname_sentiments_list:
    print(str(i) + ": " + hostname)
    i+=1
# Out:
# 0: 24.mk
# 1: fokus.mk
# 2: mk.voanews.com
# 3: kanal5.com.mk
# 4: www.slobodnaevropa.mk
# 5: 360stepeni.mk
# 6: mk.tv21.tv
# 7: sitel.com.mk
# 8: alsat.mk
# 9: netpress.com.mk

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

data = hostname_sentiments_list
# CHOOSE THE INDEX FOR THE NEWS PORTAL YOU WANT TO FIND INFORMATION FOR
hostname_index = 3

# %%
# WITHOUT COLOR INTENSITY BASED ON COUNT

# Specify the entity types you want to include in the word clouds
desired_types = ['ORG', 'PERSON', 'LOC']

# Extract entities of the desired type and their respective counts
word_frequencies = {entity: details['count_positive'] if details['label'] == 'POSITIVE' else details['count_negative'] 
                    for entity, details in data[hostname_index][1].items() if details['type'] in desired_types}

def color_func(word, **kwargs):
    label = data[hostname_index][1][word]['label']
    if label == 'POSITIVE':
        return "green"
    elif label == 'NEGATIVE':
        return "red"
    return "black"  # default

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white", color_func=color_func).generate_from_frequencies(word_frequencies)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title(f"Entities of type {', '.join(desired_types)} from " + data[hostname_index][0], fontsize=18, pad=20)
plt.show()

# %%
# WITH COLOR INTENSITY BASED ON COUNT
# Green means positive sentiment for entity
# Red means negative sentiment for entity
# Darker shades mean that the positive/negative count is big
# Lighter shades mean that the positive/negative count is small
import colorsys

desired_types = ['ORG', 'PERSON', 'LOC']

word_frequencies = {entity: details['count_positive'] if details['label'] == 'POSITIVE' else details['count_negative'] 
                    for entity, details in data[hostname_index][1].items() if details['type'] in desired_types}

max_frequency = max(word_frequencies.values())
min_frequency = min(word_frequencies.values())

def adjust_color_intensity(color, frequency):
    # Adjust the color intensity based on frequency
    ratio = (frequency - min_frequency) / (max_frequency - min_frequency)
    # Convert RGB to HLS
    h, l, s = colorsys.rgb_to_hls(*color)
    # Adjust lightness based on the ratio
    l = l * (1 - 0.5 * ratio)
    # Convert back to RGB
    return '#%02x%02x%02x' % tuple(round(i * 255) for i in colorsys.hls_to_rgb(h, l, s))

def color_func(word, **kwargs):
    details = data[hostname_index][1][word]
    label = details['label']
    if label == 'POSITIVE':
        count = details['count_positive']
        return adjust_color_intensity((0, 1, 0), count)  # RGB for green
    elif label == 'NEGATIVE':
        count = details['count_negative']
        return adjust_color_intensity((1, 0, 0), count)  # RGB for red
    return "black"

wordcloud = WordCloud(width=800, height=400, background_color="white", color_func=color_func).generate_from_frequencies(word_frequencies)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title(f"Entities of type {', '.join(desired_types)} from " + data[hostname_index][0], fontsize=18, pad=20)
plt.show()

# %%
data[3][1]["Kumanovo"]
# Out:
# {'type': 'ORG',
#  'label': 'NEGATIVE',
#  'total_positive': 0,
#  'total_negative': 2.673769950866699,
#  'count_positive': 0,
#  'count_negative': 3,
#  'score': 0.8912566502888998}

# %%
# Extract entities and their respective counts (here I'm using the positive counts) only if their label is POSITIVE
word_frequencies = {entity: details['count_positive'] for entity, details in data[hostname_index][1].items() if details['label'] == 'POSITIVE' and details['type'] in desired_types}

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_frequencies)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title(f"Entities of type {', '.join(desired_types)} with positive sentiment from " + data[hostname_index][0], fontsize=18, pad=20)
plt.show()

# %%
# Extract entities and their respective counts (here I'm using the negative counts) only if their label is NEGATIVE
word_frequencies = {entity: details['count_negative'] for entity, details in data[hostname_index][1].items() if details['label'] == 'NEGATIVE' and details['type'] in desired_types}

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_frequencies)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title(f"Entities of type {', '.join(desired_types)} with negative sentiment from " + data[hostname_index][0], fontsize=18, pad=20)
plt.show()

# %%
# # Find entities that show up the most in all news portals
# for hostname, sentiment in hostname_sentiments_list:
    
print("News portals and how many times they mention an entity:\n")
    
for hostname, entity_sentiment_map in hostname_sentiments_list:
    # Creates a list of tuples (entity_name, total_mentions)
    mentions = [(entity, details['count_positive'] + details['count_negative']) for entity, details in entity_sentiment_map.items()]
    
    sorted_mentions = sorted(mentions, key=lambda x: x[1], reverse=True)
    
    top_20_entities = sorted_mentions[:20]
    
    print(hostname)
    for entity, count in top_20_entities:
        print(f"  {entity}: {count} mentions")
    print("\n")
# Out:
# News portals and how many times they mention an entity:
#
# 24.mk
#   MANU: 5 mentions
#   760: 4 mentions
#   yesterday: 4 mentions
#   Gunzburg: 4 mentions
#   Russia: 4 mentions
#   the beginning of May: 3 mentions
#   Skopje: 3 mentions
#   US: 3 mentions
#   the United States: 3 mentions
#   the middle of the: 3 mentions
#   85-hour: 3 mentions
#   early May: 3 mentions
#   the past 24 hours: 3 mentions
#   the end of the summer: 3 mentions
#   14: 2 mentions
#   Kumanovo: 2 mentions
#   six: 2 mentions
#   Prilep: 2 mentions
#   late April: 2 mentions
#   103: 2 mentions
#
#
# fokus.mk
#   first: 6 mentions
#   today: 4 mentions
#   Austria: 4 mentions
#   the last 24 hours: 4 mentions
#   Zaev: 4 mentions
#   third: 3 mentions
#   67: 3 mentions
#   Vienna: 3 mentions
#   Spain: 3 mentions
#   September: 3 mentions
#   660,000: 3 mentions
#   2019: 2 mentions
#   2020: 2 mentions
#   Easter 84: 2 mentions
#   the past 24 hours: 2 mentions
#   Elisa: 2 mentions
#   28: 2 mentions
#   Kovid-19: 2 mentions
#   three: 2 mentions
#   daily: 2 mentions
#
#
# mk.voanews.com
#   Easter: 4 mentions
#   Friday: 3 mentions
#   one: 3 mentions
#   Tuesday: 2 mentions
#   morning: 2 mentions
#   tomorrow: 2 mentions
#   Filipce: 2 mentions
#   Kumanovo: 2 mentions
#   6: 2 mentions
#   Bitola: 2 mentions
#   Strumica: 2 mentions
#   today: 1 mentions
#   Health: 1 mentions
#   Venko Filipce: 1 mentions
#   the Commission for Infectious Diseases: 1 mentions
#   next weekend: 1 mentions
#   the following week: 1 mentions
#   the days: 1 mentions
#   the weekend: 1 mentions
#   Monday: 1 mentions
#
#
# kanal5.com.mk
#   Macedonian: 16 mentions
#   Mickoski: 13 mentions
#   today: 8 mentions
#   Bulgarian: 6 mentions
#   Kovid: 5 mentions
#   Slavic: 5 mentions
#   SDSM: 5 mentions
#   Zaev: 5 mentions
#   the Republic of Macedonia: 4 mentions
#   Today: 4 mentions
#   first: 4 mentions
#   Easter: 4 mentions
#   the past 24 hours: 4 mentions
#   Citizens: 4 mentions
#   14 days: 4 mentions
#   20: 3 mentions
#   one: 3 mentions
#   yesterday: 3 mentions
#   Osmani: 3 mentions
#   Kumanovo: 3 mentions
#
#
# www.slobodnaevropa.mk
#   Hungary: 4 mentions
#   Viktor Orban: 1 mentions
#   last night: 1 mentions
#   980: 1 mentions
#   66: 1 mentions
#   April 11.Orban: 1 mentions
#   Easter: 1 mentions
#   Last week: 1 mentions
#   the Hungary Parliament: 1 mentions
#   Orban: 1 mentions
#
#
# 360stepeni.mk
#   Mickoski: 5 mentions
#   Macedonian: 3 mentions
#   VMRO-DPMNE: 2 mentions
#   today: 2 mentions
#   the Ministry of Finance: 2 mentions
#   Government: 2 mentions
#   three: 2 mentions
#   March: 2 mentions
#   Mickoski: The Ministry of Finance: 1 mentions
#   The Ministry of Finance: 1 mentions
#   50 percent: 1 mentions
#   Christian Mickoski: 1 mentions
#   Decree: 1 mentions
#   Nake Zulev: 1 mentions
#   Oliver Spasovski: 1 mentions
#   July: 1 mentions
#   September: 1 mentions
#   second: 1 mentions
#   the beginning of this year: 1 mentions
#   2021.Secondly: 1 mentions
#
#
# mk.tv21.tv
#   two: 8 mentions
#   today: 6 mentions
#   Easter: 6 mentions
#   Filipce: 6 mentions
#   Italy: 6 mentions
#   Skopje: 5 mentions
#   first: 5 mentions
#   Spain: 5 mentions
#   15: 4 mentions
#   Jesus Christ: 4 mentions
#   Venko Filipce: 4 mentions
#   One: 4 mentions
#   Stip: 3 mentions
#   1: 3 mentions
#   5: 3 mentions
#   Christian: 3 mentions
#   Kalajdziev: 3 mentions
#   Assembly: 3 mentions
#   Parliament: 3 mentions
#   Kumanovo: 3 mentions
#
#
# sitel.com.mk
#   Over 200: 3 mentions
#   2: 2 mentions
#   5: 2 mentions
#   Corona Viris: 1 mentions
#   SIA Strumica: 1 mentions
#   ten: 1 mentions
#   “SIA Strumica: 1 mentions
#   16: 1 mentions
#   20: 1 mentions
#   186: 1 mentions
#   211: 1 mentions
#   Article 34A: 1 mentions
#   the SIA Strumica: 1 mentions
#   The Strumica Basic Court: 1 mentions
#   the Basic Public Prosecutor's Office: 1 mentions
#   66: 1 mentions
#   epidemicA: 1 mentions
#   10: 1 mentions
#   3,000: 1 mentions
#   denar counter: 1 mentions
#
#
# alsat.mk
#   Replica Watches: 2 mentions
#   Ferizaj: 1 mentions
#   Miturg: 1 mentions
#   Aleksandar Vuçiq: 1 mentions
#   Gjug: 1 mentions
#   COMMONGNITIONS: 1 mentions
#   ON THE: 1 mentions
#   PETERS: 1 mentions
#   COMMONGRARE: 1 mentions
#   QUYTETIN: 1 mentions
#   m1 abrams' q p p p k k k k: 1 mentions
#   Duke: 1 mentions
#   Gazetar: 1 mentions
#   Adnan Qaili Mbi: 1 mentions
#   50: 1 mentions
#   FAJIN: 1 mentions
#   The BASHKUARA JOEME: 1 mentions
#   AIR CONDITIONAL: 1 mentions
#   Blut"The FURTHERS OF THE COMPONIMITIONAL: 1 mentions
#   the Inteligement of the Inteligibilityin: 1 mentions
#
#
# netpress.com.mk
#   Delcevo: 4 mentions
#   Trabotivishte: 2 mentions
#   the Delcevo Territorial Fire Brigade: 1 mentions
#   Prvomajska Street: 1 mentions
#   TPPE Delchevo: 1 mentions
#   19:20: 1 mentions
#   Saturday: 1 mentions
#   six: 1 mentions
#   second: 1 mentions
#   a week: 1 mentions
#   a few days ago: 1 mentions

# %%
def get_sentiment_difference(entity_data_1, entity_data_2):
    portal1_sentiment = entity_data_1.get('total_positive', 0) - entity_data_1.get('total_negative', 0)
    portal2_sentiment = entity_data_2.get('total_positive', 0) - entity_data_2.get('total_negative', 0)
    return abs(portal1_sentiment - portal2_sentiment)

def find_top_differences(data):
    diff_list = []
    for i in range(len(data)):
        for j in range(i + 1, len(data)):
            portal1, portal2 = data[i], data[j]
            common_entities = set(portal1[1].keys()) & set(portal2[1].keys())
            for entity in common_entities:
                diff_value = get_sentiment_difference(portal1[1][entity], portal2[1][entity])
                diff_list.append(((portal1[0], portal2[0], entity), diff_value))
    
    diff_list.sort(key=lambda x: x[1], reverse=True)
    return [x[0] for x in diff_list[:10]]

top_diff = find_top_differences(data)
print("These are the news sites and the entities that they have the most drastically different opinions on:\n")
print(top_diff)
# Out:
# These are the news sites and the entities that they have the most drastically different opinions on:
#
# [('kanal5.com.mk', '360stepeni.mk', 'Macedonian'), ('24.mk', 'mk.tv21.tv', 'Skopje'), ('mk.voanews.com', 'mk.tv21.tv', 'Skopje'), ('kanal5.com.mk', 'mk.tv21.tv', 'Kovid'), ('24.mk', 'kanal5.com.mk', 'Easter'), ('kanal5.com.mk', 'netpress.com.mk', 'Delcevo'), ('mk.voanews.com', 'kanal5.com.mk', 'Easter'), ('fokus.mk', 'mk.tv21.tv', '1'), ('24.mk', 'mk.tv21.tv', '1'), ('kanal5.com.mk', 'mk.tv21.tv', 'Parliament')]

# %%
for hostname, entity_sentiments in data:
    if(hostname == "kanal5.com.mk" or hostname == "netpress.com.mk"):
        print(hostname + ": " + str(entity_sentiments["Delcevo"]))
# Out:
# kanal5.com.mk: {'type': 'PERSON', 'label': 'POSITIVE', 'total_positive': 0.9989245533943176, 'total_negative': 0, 'count_positive': 1, 'count_negative': 0, 'score': 0.9989245533943176}
# netpress.com.mk: {'type': 'PERSON', 'label': 'NEGATIVE', 'total_positive': 0, 'total_negative': 3.561493992805481, 'count_positive': 0, 'count_negative': 4, 'score': 0.8903734982013702}

# %%
# WRITE NEWS TO FILE
################################################################################################################################
# file_path = "final.txt"
# delimiter = "____###DELIMITER###____"  # Choose a delimiter that won't appear in your data

# with open(file_path, "w", encoding="utf-8") as file:
#     # Iterate through the map and write each key-value pair
#     for key, value in translated_texts.items():
#         file.write(f"{key}{delimiter}{value}\n")  # Add a newline character after each pair

# print("Key-value pairs written to the file successfully.")

# %%
# READ NEWS FROM FILE
################################################################################################################################
# file_path = "final.txt"
# delimiter = "____###DELIMITER###____"  # The same delimiter you used while saving

# read_map = {}

# with open(file_path, "r", encoding="utf-8") as file:
#     for line in file:
#         key, value = line.strip().split(delimiter, 1)
#         read_map[key] = value

# print("Key-value pairs read from the file:", read_map)
